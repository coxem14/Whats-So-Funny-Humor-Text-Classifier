# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_colwidth', 0)

from os import path
from PIL import Image
import os

from collections import Counter

from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, roc_curve, roc_auc_score, silhouette_samples, silhouette_score
from sklearn.neural_network import MLPClassifier
from sklearn.cluster import KMeans

from pprint import pprint

import string
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer, word_tokenize
from nltk.stem.porter import PorterStemmer as PS

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns

from wordcloud import WordCloud, ImageColorGenerator
# Out:
# [nltk_data] Downloading package stopwords to /Users/coxem/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## EDA

# %%
texts = pd.read_csv('data/dataset.csv')
texts.head(10)
# Out:
#                                                                                     text  \
# 0  Joe biden rules out 2020 bid: 'guys, i'm not running'
# 1  Watch: darvish gave hitter whiplash with slow pitch
# 2  What do you call a turtle without its shell? dead.
# 3  5 reasons the 2016 election feels so personal
# 4  Pasco police shot mexican migrant from behind, new autopsy shows
# 5  Martha stewart tweets hideous food photo, twitter responds accordingly
# 6  What is a pokemon master's favorite kind of pasta? wartortellini!
# 7  Why do native americans hate it when it rains in april? because it brings mayflowers.
# 8  Obama's climate change legacy is impressive, imperfect and vulnerable
# 9  My family tree is a cactus, we're all pricks.
#
#    humor
# 0  False
# 1  False
# 2  True
# 3  False
# 4  False
# 5  False
# 6  True
# 7  True
# 8  False
# 9  True

# %%
texts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    200000 non-null  object
#  1   humor   200000 non-null  bool
# dtypes: bool(1), object(1)
# memory usage: 1.7+ MB

# %%
texts.humor.unique()
# Out:
# array([False,  True])

# %%
texts.humor.value_counts()
# Out:
# True     100000
# False    100000
# Name: humor, dtype: int64

# %%
texts.text[0]
# Out:
# "Joe biden rules out 2020 bid: 'guys, i'm not running'"

# %%
texts_humor = texts[texts['humor'] == True]
texts_humor.head()
# Out:
#                                                                                      text  \
# 2   What do you call a turtle without its shell? dead.
# 6   What is a pokemon master's favorite kind of pasta? wartortellini!
# 7   Why do native americans hate it when it rains in april? because it brings mayflowers.
# 9   My family tree is a cactus, we're all pricks.
# 13  How are music and candy similar? we throw away the rappers.
#
#     humor
# 2   True
# 6   True
# 7   True
# 9   True
# 13  True

# %%
texts_serious = texts[texts['humor'] == False]
texts_serious.head()
# Out:
#                                                                      text  \
# 0  Joe biden rules out 2020 bid: 'guys, i'm not running'
# 1  Watch: darvish gave hitter whiplash with slow pitch
# 3  5 reasons the 2016 election feels so personal
# 4  Pasco police shot mexican migrant from behind, new autopsy shows
# 5  Martha stewart tweets hideous food photo, twitter responds accordingly
#
#    humor
# 0  False
# 1  False
# 3  False
# 4  False
# 5  False

# %% [markdown]
# ## Train, Test, Split

# %%
X = texts['text']

# %%
y = texts['humor']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, shuffle=True, stratify=y)

# %%
# X_train

# %% [markdown]
# ## Developing Corpus Cleaning Pipeline

# %% [markdown]
# > * For my Naive Bayes model, I wanted to try to use a stemmed corpus prior to fit_transforming the tfidf vectorizer, because without it, there were a lot of duplicated words in various forms (e.g. charged, charge, charges, etc.). In order to do this, I had to write a function to which would stem the corpus, and I just went ahead and cleaned the text up (removed punctuation, stopwords, and used porter stemmer) then put it back in the raw corpus format (list of strings).
# > * This ended up resulting in a lower accuracy, but worked really well for making my wordcloud

# %%
# texts_list = [text.lower() for text in X]
# texts_list

# %%
# tokenizer = RegexpTokenizer("[\w']+")

# %%
# tokens = list(map(tokenizer.tokenize, texts_list))
# tokens

# %%
# punc = set(string.punctuation)
# tokens_no_punc = [[word for word in words if word not in punc]
#         for words in tokens]
# tokens_no_punc

# %%
# s_words = set(stopwords.words('english'))
# tokens_no_sw = [[word for word in words if word not in s_words]
#         for words in tokens_no_punc]
# tokens_no_sw

# %%
# porter = PS()
# texts_ps = [[porter.stem(word) for word in text] for text in tokens_no_sw]
# texts_ps

# %%
# texts_ps_joined = [' '.join(word) for word in texts_ps]
# texts_ps_joined

# %%
def clean_corpus(X):
    '''
    Takes in a series or list of strings.
    Returns one string of cleaned text.
    '''
    # lowercase the strings
    corpus = [text.lower() for text in X] 

    # declare regular expression tokenizer
    # split strings into words while keeping contractions together
    tokenizer = RegexpTokenizer("[\w']+")
    tokens = list(map(tokenizer.tokenize, corpus)) 
    
    # remove punctuation
    punc = set(string.punctuation)
    tokens_no_punc = [[word for word in words if word not in punc]
        for words in tokens]
   
    # remove stopwords
    s_words = set(stopwords.words('english'))
    tokens_no_sw = [[word for word in words if word not in s_words]
        for words in tokens_no_punc]
    
    # stem the words to get rid of multiple forms of the same word
    porter = PS()
    tokens_stemmed = [[porter.stem(word) for word in text] for text in tokens_no_sw]
    
    # join all words into one string
    cleaned_corpus = [' '.join(word) for word in tokens_stemmed]
    
    return cleaned_corpus

# %%
# def old_clean_corpus(X):
#     '''
#     Takes in a series or list of strings.
#     Returns one string of cleaned text.
#     '''
#     # lowercase the strings
#     corpus = [text.lower() for text in X] 

#     # declare regular expression tokenizer
#     # split strings into words while keeping contractions together
#     tokens = list(map(word_tokenize, corpus)) 
    
#     # remove punctuation
#     punc = set(string.punctuation)
#     tokens_no_punc = [[word for word in words if word not in punc]
#         for words in tokens]
   
#     # remove stopwords
#     s_words = set(stopwords.words('english'))
#     tokens_no_sw = [[word for word in words if word not in s_words]
#         for words in tokens_no_punc]
    
#     # stem the words to get rid of multiple forms of the same word
#     porter = PS()
#     tokens_stemmed = [[porter.stem(word) for word in text] for text in tokens_no_sw]
    
#     # join all words into one string
#     cleaned_corpus = [' '.join(word) for word in tokens_stemmed]
    
#     return cleaned_corpus

# %% [markdown]
# ## Humor Word Cloud and Serious Word Cloud

# %%
#https://amueller.github.io/word_cloud/auto_examples/masked.html#sphx-glr-auto-examples-masked-py

# Define path
path_ = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# read the mask / color image taken from
laugh_emoji = np.array(Image.open(path.join(path_, "images/rolling-on-the-floor-laughing.png")))
straight_face_emoji = np.array(Image.open(path.join(path_, "images/expressionless-face.png")))

# create coloring from image
humor_image_colors = ImageColorGenerator(laugh_emoji)
serious_image_colors = ImageColorGenerator(straight_face_emoji)

# %%
# def old_word_cloud(corpus, wordcloud_obj):
#     cleaned_corpus = ' '.join(old_clean_corpus(corpus))
#     word_cloud = wordcloud_obj
#     word_cloud.generate(cleaned_corpus)
#     return word_cloud

# %%
# wc_humor_old = WordCloud(background_color="black", relative_scaling=0.5, max_words=None, mask=laugh_emoji, max_font_size=50)

# %%
# old_word_cloud_humor = old_word_cloud(texts_humor.text, wc_humor_old)

# %%
# fig, axes = plt.subplots(1, 2, figsize=(14,10))
# axes[0].imshow(old_word_cloud_humor.recolor(color_func=humor_image_colors), interpolation="bilinear")
# axes[1].imshow(laugh_emoji, cmap=plt.cm.gray, interpolation="bilinear")

# for ax in axes:
#     ax.set_axis_off()

# %%
def make_word_cloud(corpus, wordcloud_obj):
    cleaned_corpus = ' '.join(clean_corpus(corpus))
    word_cloud = wordcloud_obj
    word_cloud.generate(cleaned_corpus)
    return word_cloud

# %%
wc_humor = WordCloud(background_color="black", relative_scaling=0.5, max_words=None, mask=laugh_emoji, max_font_size=50)

# %%
word_cloud_humor = make_word_cloud(texts_humor.text, wc_humor)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,10))
axes[0].imshow(word_cloud_humor.recolor(color_func=humor_image_colors), interpolation="bilinear")
axes[1].imshow(laugh_emoji, cmap=plt.cm.gray, interpolation="bilinear")

for ax in axes:
    ax.set_axis_off()
    
#plt.savefig('wc_humor.png')

# %%
def get_top_words(word_cloud, num_words=10):
    word_list = list(word_cloud.words_)
    top_words = word_list[:num_words]
    return f'The top {num_words} words are: {", ".join(top_words)}'

# %%
get_top_words(word_cloud_humor)
# Out:
# "The top 10 words are: call, say, one, know, go, make, what', joke, peopl, want"

# %%
wc_serious = WordCloud(background_color="black", relative_scaling=0.5, max_words=None, mask=straight_face_emoji, max_font_size=50)

# %%
word_cloud_serious = make_word_cloud(texts_serious.text, wc_serious)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14,10))
axes[0].imshow(wc_serious.recolor(color_func=serious_image_colors), interpolation="bilinear")
axes[1].imshow(straight_face_emoji, cmap=plt.cm.gray, interpolation="bilinear")
for ax in axes:
    ax.set_axis_off()

#plt.savefig('wc_serious.png')

# %%
get_top_words(word_cloud_serious)
# Out:
# 'The top 10 words are: photo, video, new, say, donald trump, trump, make, one, kid, take'

# %% [markdown]
# ## Featurizing the Text

# %%
# tfid = TfidfVectorizer(max_features=1000)
# text_train = tfid.fit_transform(X_train_clean)
# feature_names = tfid.get_feature_names()
# feature_names

# %%
# tfid = TfidfVectorizer(stop_words='english', max_features=1000)
# text_train = tfid.fit_transform(X_train)
# feature_names = tfid.get_feature_names()
# feature_names

# %%
# len(feature_names)

# %%
# text_train_df = pd.DataFrame(text_train.todense(), columns = tfid.vocabulary_)
# text_train_df.head()

# %%
#text_train_df.call.unique()

# %%
# X_text_train = text_train.toarray()
# X_text_train

# %%
# X_text_train.shape

# %% [markdown]
# ## Fitting the Naive Bayes models

# %% [markdown]
# > * From sklearn: Multinomial implements the naive Bayes algorithm for multinomially distributed data, and is one of the two classic naive Bayes variants used in text classification (where the data are typically represented as word vector counts, although tf-idf vectors are also known to work well in practice).
# > * Seems like the uncleaned model performs better than the cleaned model
#
#
# > * From sklearn: BernoulliNB implements the naive Bayes training and classification algorithms for data that is distributed according to multivariate Bernoulli distributions; i.e., there may be multiple features but each one is assumed to be a binary-valued (Bernoulli, boolean) variable. In the case of text classification, word occurrence vectors (rather than word count vectors) may be used to train and use this classifier. BernoulliNB might perform better on some datasets, especially those with shorter documents. It is advisable to evaluate both models, if time permits.
# > * Seems like BernoulliNB performs slightly better than MultinomialNB

# %%
X_train_clean = clean_corpus(X_train)

# %%
X_test_clean = clean_corpus(X_test)

# %% [markdown]
# #### MultinomialNB

# %%
def fit_predict_model_accuracy(pipeline, X_train, y_train, X_test, y_test):
    pipeline.fit(X_train, y_train)
    predicted = pipeline.predict(X_test)
    accuracy = np.mean(predicted == y_test)
    print("\nThe accuracy on the test set is {0:0.3f}.".format(accuracy))
    return predicted

# %%
mnb_pipeline = Pipeline([('tfidf', TfidfVectorizer()),
                        ('model', MultinomialNB())])

mnb_pipeline_clean = Pipeline([('tfidf', TfidfVectorizer()),
                        ('model', MultinomialNB())])

# %%
mnb_predicted = fit_predict_model_accuracy(mnb_pipeline, X_train, y_train, X_test, y_test)
# Out:
# The accuracy on the test set is 0.917.

# %%
mnb_predicted_clean = fit_predict_model_accuracy(mnb_pipeline_clean, X_train_clean, y_train, X_test_clean, y_test)
# Out:
# The accuracy on the test set is 0.894.

# %% [markdown]
# #### BernoulliNB

# %%
bnb_pipeline = Pipeline([('tfidf', TfidfVectorizer()),
                        ('model', BernoulliNB())])

bnb_pipeline_clean = Pipeline([('tfidf', TfidfVectorizer()),
                        ('model', BernoulliNB())])

# %%
bnb_predicted = fit_predict_model_accuracy(bnb_pipeline, X_train, y_train, X_test, y_test)
# Out:
# The accuracy on the test set is 0.922.

# %%
bnb_predicted_clean = fit_predict_model_accuracy(bnb_pipeline_clean, X_train_clean, y_train, X_test_clean, y_test)
# Out:
# The accuracy on the test set is 0.896.

# %% [markdown]
# ## Confusion Matrices

# %% [markdown]
# > * Accuracy - How often does the model predict correctly, overall?
# > * Precision - When the model predicts the positive result, how often is it correct?
# > * Recall - When it is actually the positive result, how often does it predict correctly?
#
# > * The model with the best scores overall is the Bernoulli Naive Bayes using the uncleaned data.
#
# > * Is it more "dangerous" to believe something meant to be humorous is serious (false negative), or to believe something meant to be serious is humorous (false positive)? Orson Welles "The War of the Worlds" panic vs potentially neglecting someone in need (boy who cried wolf - or guy who got stuck in an ATM).
# > * Personally, I think it's more dangerous to believe something meant to be serious is humorous (false positive in this case)
#
# > * I want to figure out what words it is having trouble with

# %%
def create_confusion_matrix(y_test, predicted, targets, ax):
    cm = confusion_matrix(y_test, predicted)
    sns.set(font_scale=1.7)
    sns.heatmap(cm.T, square = True, annot = True, fmt = 'd', cmap='magma',
            xticklabels = targets, yticklabels = targets, ax=ax)

# %%
fig, ax = plt.subplots(figsize=(6,6))
create_confusion_matrix(y_test, mnb_predicted, y.unique(), ax=ax)
ax.set_xlabel('Actual Labels', fontsize=18)
ax.set_ylabel('Predicted Labels', fontsize=18)
ax.set_title('Multinomial Naive Bayes', fontsize=20);

# %%
fig, axs = plt.subplots(2, 2, figsize=(16,16))
preds = [mnb_predicted, mnb_predicted_clean, bnb_predicted, bnb_predicted_clean]
titles = ['Multinomial Naive Bayes', 'Multinomial Naive Bayes - Cleaned', 'Bernoulli Naive Bayes', 'Bernoulli Naive Bayes - Cleaned']
i = 0
for pred, ax in zip(preds, axs.flatten()):
    create_confusion_matrix(y_test, pred, y.unique(), ax=ax)
    ax.set_xlabel('Actual Labels', fontsize=20)
    ax.set_ylabel('Predicted Labels', fontsize=20)
    ax.set_title(titles[i], fontsize=20)
    i += 1
    
#plt.savefig('confusion_matrices.png')

# %%
preds = [mnb_predicted, mnb_predicted_clean, bnb_predicted, bnb_predicted_clean]
titles = ['Multinomial Naive Bayes', 'Multinomial Naive Bayes - Cleaned', 'Bernoulli Naive Bayes', 'Bernoulli Naive Bayes - Cleaned']
accs = []
precs = []
recs = []
for idx, pred in enumerate(preds):
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    accs.append(accuracy)
    precs.append(precision)
    recs.append(recall)
    print(f'\nModel: {titles[idx]}')
    print("The accuracy on the test set is {0:0.3f}.".format(accuracy))
    print("The precision on the test set is {0:0.3f}.".format(precision))
    print("The recall on the test set is {0:0.3f}.".format(recall))

print(f'\nThe model with the highest accuracy: {titles[int(np.where(accs == np.max(accs))[0])]}')
print(f'The model with the highest precision: {titles[int(np.where(precs == np.max(precs))[0])]}')
print(f'The model with the highest recall: {titles[int(np.where(recs == np.max(recs))[0])]}')
# Out:
# Model: Multinomial Naive Bayes
# The accuracy on the test set is 0.917.
# The precision on the test set is 0.902.
# The recall on the test set is 0.937.
#
# Model: Multinomial Naive Bayes - Cleaned
# The accuracy on the test set is 0.894.
# The precision on the test set is 0.890.
# The recall on the test set is 0.898.
#
# Model: Bernoulli Naive Bayes
# The accuracy on the test set is 0.922.
# The precision on the test set is 0.909.
# The recall on the test set is 0.938.
#
# Model: Bernoulli Naive Bayes - Cleaned
# The accuracy on the test set is 0.896.
# The precision on the test set is 0.882.
# The recall on the test set is 0.914.
#
# The model with the highest accuracy: Bernoulli Naive Bayes
# The model with the highest precision: Bernoulli Naive Bayes
# The model with the highest recall: Bernoulli Naive Bayes

# %%
# conf_mat_clean = confusion_matrix(y_test, predicted_clean)
# tn, fp, fn, tp = conf_mat_clean.ravel()
# tn, fp, fn, tp #making sure the confusion matrix is outputting the correct information

# %%
# cm_display = ConfusionMatrixDisplay(conf_mat).plot()

# %% [markdown]
# ## Testing the model(s) on new (made up) data

# %%
def get_predictions(text, pipeline):
    prediction = pipeline.predict([text])
    return prediction

# %%
# humorous - https://www.fatherly.com/play/best-coronavirus-jokes/
# serious - https://www.cdc.gov/coronavirus/2019-ncov/prevent-getting-sick/prevention.html
# text_humorous_1 = 'My mom always told me I wouldn’t accomplish anything by lying in bed all day. But look at me now, ma! I’m saving the world!'
# text_humorous_2 = 'If I keep stress-eating at this level, the buttons on my shirt will start socially distancing from each other.'
# text_serious_1 = 'To help prevent the spread of COVID-19, everyone should wear a mask in public.'
# text_serious_2 = 'Avoid close contact with people who are sick.'

# %%
def get_multiple_predictions(text_list, label_list, pipeline):
    for idx, text in enumerate(text_list):
        if get_predictions(text=text, pipeline=pipeline)[0] == True:
            pred = 'Humorous'
        else: pred = 'Serious'
        print(f'Text: {text}\nPrediction: {pred}\nLabel: {label_list[idx]}\n')

# %%
google_form_responses = pd.read_csv('data/google_form_responses.csv')

# %%
google_form_responses.rename(columns={'Short Text:': 'text', 'True or False - The text is humorous.': 'humor'}, inplace=True)
google_form_responses
# Out:
#             Timestamp Your Name:  \
# 0  12/3/2020 9:34:39   Heather
# 1  12/3/2020 9:35:55   Heather
# 2  12/3/2020 9:43:14   George
# 3  12/3/2020 10:20:32  nico
# 4  12/3/2020 11:27:47  Mario
# 5  12/3/2020 11:56:25  Erin
# 6  12/3/2020 11:56:42  Erin
# 7  12/3/2020 11:56:56  Erin
# 8  12/3/2020 11:57:13  Erin
# 9  12/3/2020 12:34:58  Jamie
#
#                                                                                                                                        text  \
# 0  When the prosecuting attorney asked Gucci Mane if he was guilty he said, 'bitch I might be.'
# 1  Camus says that when you wish yourself into the future you commit suicide by wishing yourself closer to your death.
# 2  How did the random variable get into the club? By showing a fake i.i.d.
# 3  Laugh it up! Humor is universal across human cultures — and fuels psychological research on everything from social perception to emotion
# 4  Saddest 6 word story: "Soup of the Day: No Soup."
# 5  My mom always told me I wouldn’t accomplish anything by lying in bed all day. But look at me now, ma! I’m saving the world!
# 6  If I keep stress-eating at this level, the buttons on my shirt will start socially distancing from each other.
# 7  To help prevent the spread of COVID-19, everyone should wear a mask in public.
# 8  Avoid close contact with people who are sick.
# 9  What did one support vector say to another support vector? I feel so marginalized.
#
#    humor
# 0  True
# 1  False
# 2  True
# 3  False
# 4  True
# 5  True
# 6  True
# 7  False
# 8  False
# 9  True

# %%
X_new = google_form_responses.copy()
X_new
# Out:
#             Timestamp Your Name:  \
# 0  12/3/2020 9:34:39   Heather
# 1  12/3/2020 9:35:55   Heather
# 2  12/3/2020 9:43:14   George
# 3  12/3/2020 10:20:32  nico
# 4  12/3/2020 11:27:47  Mario
# 5  12/3/2020 11:56:25  Erin
# 6  12/3/2020 11:56:42  Erin
# 7  12/3/2020 11:56:56  Erin
# 8  12/3/2020 11:57:13  Erin
# 9  12/3/2020 12:34:58  Jamie
#
#                                                                                                                                        text  \
# 0  When the prosecuting attorney asked Gucci Mane if he was guilty he said, 'bitch I might be.'
# 1  Camus says that when you wish yourself into the future you commit suicide by wishing yourself closer to your death.
# 2  How did the random variable get into the club? By showing a fake i.i.d.
# 3  Laugh it up! Humor is universal across human cultures — and fuels psychological research on everything from social perception to emotion
# 4  Saddest 6 word story: "Soup of the Day: No Soup."
# 5  My mom always told me I wouldn’t accomplish anything by lying in bed all day. But look at me now, ma! I’m saving the world!
# 6  If I keep stress-eating at this level, the buttons on my shirt will start socially distancing from each other.
# 7  To help prevent the spread of COVID-19, everyone should wear a mask in public.
# 8  Avoid close contact with people who are sick.
# 9  What did one support vector say to another support vector? I feel so marginalized.
#
#    humor
# 0  True
# 1  False
# 2  True
# 3  False
# 4  True
# 5  True
# 6  True
# 7  False
# 8  False
# 9  True

# %%
google_form_responses.loc[(google_form_responses.humor == True), 'humor'] = 'Humorous'

# %%
google_form_responses.loc[(google_form_responses.humor == False), 'humor'] = 'Serious'

# %%
text_list = list(google_form_responses.text)
label_list = list(google_form_responses.humor)
get_multiple_predictions(text_list=text_list, label_list=label_list, pipeline=bnb_pipeline)
# Out:
# Text: When the prosecuting attorney asked Gucci Mane if he was guilty he said, 'bitch I might be.'
# Prediction: Humorous
# Label: Humorous
#
# Text: Camus says that when you wish yourself into the future you commit suicide by wishing yourself closer to your death.
# Prediction: Humorous
# Label: Serious
#
# Text: How did the random variable get into the club? By showing a fake i.i.d.
# Prediction: Humorous
# Label: Humorous
#
# Text: Laugh it up! Humor is universal across human cultures — and fuels psychological research on everything from social perception to emotion
# Prediction: Serious
# Label: Serious
#
# Text: Saddest 6 word story: "Soup of the Day: No Soup."
# Prediction: Humorous
# Label: Humorous
#
# Text: My mom always told me I wouldn’t accomplish anything by lying in bed all day. But look at me now, ma! I’m saving the world!
# Prediction: Humorous
# Label: Humorous
#
# Text: If I keep stress-eating at this level, the buttons on my shirt will start socially distancing from each other.
# Prediction: Humorous
# Label: Humorous
#
# Text: To help prevent the spread of COVID-19, everyone should wear a mask in public.
# Prediction: Serious
# Label: Serious
#
# Text: Avoid close contact with people who are sick.
# Prediction: Humorous
# Label: Serious
#
# Text: What did one support vector say to another support vector? I feel so marginalized.
# Prediction: Humorous
# Label: Humorous

# %%
X_test_new = X_new['text']
y_test_new = X_new['humor']

# %%
bnb_predicted_new = bnb_pipeline.predict(X_test_new)

# %%
fig, ax = plt.subplots(figsize=(6,6))
create_confusion_matrix(y_test_new, bnb_predicted_new, y_test_new.unique(), ax=ax)
ax.set_xlabel('Actual Labels', fontsize=18)
ax.set_ylabel('Predicted Labels', fontsize=18)
ax.set_title('Bernoulli Naive Bayes', fontsize=20);

# %%
accuracy_new = accuracy_score(y_test_new, bnb_predicted_new)
precision_new = precision_score(y_test_new, bnb_predicted_new)
recall_new = recall_score(y_test_new, bnb_predicted_new)

print("The accuracy on the test set is {0:0.3f}.".format(accuracy_new))
print("The precision on the test set is {0:0.3f}.".format(precision_new))
print("The recall on the test set is {0:0.3f}.".format(recall_new))
# Out:
# The accuracy on the test set is 0.800.
# The precision on the test set is 0.750.
# The recall on the test set is 1.000.

# %% [markdown]
# ## ROC Curve

# %% [markdown]
# > * ROC - When it is actually the negative result, how often does it predict correctly?

# %%
y_test_values = y_test.values
y_test_values = np.where(y_test_values, 1, 0)
y_test_values
# Out:
# array([0, 1, 0, ..., 1, 0, 0])

# %%
mnb_probs = mnb_pipeline.predict_proba(X_test)[:, 1]
mnb_fpr, mnb_tpr, mnb_thresholds = roc_curve(y_test_values, mnb_probs)

mnb_probs_clean = mnb_pipeline_clean.predict_proba(X_test_clean)[:, 1]
mnb_fpr_clean, mnb_tpr_clean, mnb_thresholds_clean = roc_curve(y_test_values, mnb_probs_clean)

bnb_probs = bnb_pipeline.predict_proba(X_test)[:, 1]
bnb_fpr, bnb_tpr, bnb_thresholds = roc_curve(y_test_values, bnb_probs)

bnb_probs_clean = bnb_pipeline_clean.predict_proba(X_test_clean)[:, 1]
bnb_fpr_clean, bnb_tpr_clean, bnb_thresholds_clean = roc_curve(y_test_values, bnb_probs_clean)

x = np.linspace(0, 1)

plt.style.use('default')

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(bnb_fpr, bnb_tpr, color = 'blue', label='Bernoulli Naive Bayes')
ax.plot(mnb_fpr, mnb_tpr, color ='purple', linestyle='--', label='Multinomial Naive Bayes')
ax.plot(bnb_fpr_clean, bnb_tpr_clean, color = 'red', label='Bernoulli Naive Bayes - Cleaned')
ax.plot(mnb_fpr_clean, mnb_tpr_clean, color = 'green', linestyle='--', label='Multinomial Naive Bayes - Cleaned')
ax.plot(x, x, color='black', linestyle='-.')
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Plot')
ax.legend(loc='lower right');

#plt.savefig('NB_ROC.png')

# %%
probs = [mnb_probs, bnb_probs]
titles = ['Multinomial Naive Bayes', 'Bernoulli Naive Bayes']
scores = []

for idx, prob in enumerate(probs):
    score = roc_auc_score(y_test, prob)
    scores.append(score)
    print(f'\nModel: {titles[idx]}')
    print("The ROC AUC score for the model is {0:0.3f}.".format(score))

print(f'\nThe model with the largest AUC: {titles[int(np.where(scores == np.max(scores))[0])]}')
# Out:
# Model: Multinomial Naive Bayes
# The ROC AUC score for the model is 0.975.
#
# Model: Bernoulli Naive Bayes
# The ROC AUC score for the model is 0.977.
#
# The model with the largest AUC: Bernoulli Naive Bayes

# %% [markdown]
# ## Exploring elminating top misclassified words

# %%
# def even_cleaner_corpus(X):
#     corpus = [text.lower() for text in X]
#     tokenizer = RegexpTokenizer("[\w']+")
#     tokens = list(map(tokenizer.tokenize, corpus))
    
#     punc = set(string.punctuation)
#     tokens_no_punc = [[word for word in words if word not in punc]
#         for words in tokens]
   
#     s_words = set(stopwords.words('english'))
#     add_word = ['make', 'one', 'thing', 'say', 'people', 'know', 'want', 'new', 'kid', 'go']
#     for word in add_word:
#         s_words.add(word)

#     tokens_no_sw = [[word for word in words if word not in s_words]
#         for words in tokens_no_punc]
    
#     porter = PS()
#     tokens_stemmed = [[porter.stem(word) for word in text] for text in tokens_no_sw]
    
#     new_corpus = [' '.join(word) for word in tokens_stemmed]
    
#     return new_corpus

# %%
# X_train_even_cleaner = even_cleaner_corpus(X_train)
# X_test_even_cleaner = even_cleaner_corpus(X_test)

# %%
# bnb_pipeline_even_cleaner = Pipeline([('tfidf', TfidfVectorizer()),
#                                       ('model', BernoulliNB())])

# bnb_predicted_even_cleaner = fit_predict_model_accuracy(bnb_pipeline_even_cleaner, X_train_even_cleaner, y_train, X_test_even_cleaner, y_test)

# %%
# cleaner_misclass_corpus, cleaner_fp_corpus, cleaner_fn_corpus = get_misclassified_corpus(X_test, y_test, bnb_predicted_even_cleaner)

# %%
# def make_word_cloud_even_cleaner(corpus, wordcloud):
#     corpus_clean = ' '.join(even_cleaner_corpus(corpus))
#     word_cloud = wordcloud
#     word_cloud.generate(corpus_clean)
#     return word_cloud

# %%
# cleaner_wc_misclass = WordCloud(colormap="Paired", relative_scaling=1, max_words=None, max_font_size=40)
# cleaner_word_cloud_misclass = make_word_cloud_even_cleaner(cleaner_misclass_corpus, cleaner_wc_misclass)

# cleaner_wc_fp = WordCloud(colormap="Paired", relative_scaling=1, max_words=None, max_font_size=40)
# cleaner_word_cloud_fp = make_word_cloud_even_cleaner(cleaner_fp_corpus, cleaner_wc_fp)

# cleaner_wc_fn = WordCloud(colormap="Paired", relative_scaling=1, max_words=None, max_font_size=40)
# cleaner_word_cloud_fn = make_word_cloud_even_cleaner(cleaner_fn_corpus, cleaner_wc_fn)

# %%
# fig, axs = plt.subplots(3, 1, figsize=(10,10))
# wordclouds = [cleaner_word_cloud_misclass, cleaner_word_cloud_fp, cleaner_word_cloud_fn]
# titles = ['Cleaner Top Misclassified Words', 'Cleaner Top Mistakenly Humorous Words - False Positives', 'Cleaner Top Mistakenly Serious Words - False Negatives']

# i = 0
# for wordcloud, ax in zip(wordclouds, axs.flatten()):
#     ax.imshow(wordcloud, interpolation = 'bilinear')
#     ax.set_axis_off()
#     ax.set_title(titles[i])
#     i += 1
# fig.tight_layout()

# %%
# get_top_words(cleaner_word_cloud_misclass, num_words=10)

# %%
# false_positives = np.where((y_test == False) & (bnb_predicted == True))[0]
# false_positives, len(false_positives)

# %%
# false_negatives = np.where((y_test == True) & (bnb_predicted == False))[0]
# false_negatives, len(false_negatives)

# %%
# fp_idx_samps = list(np.random.choice(false_positives, 5, replace=False))
# fp_idx_samps

# %%
# fn_idx_samps = list(np.random.choice(false_negatives, 5, replace=False))
# fn_idx_samps

# %%
# print('False Positives:')
# for idx in fp_idx_samps:
#     print(f'Quote: {X_test.iloc[idx]}\n Label: {y_test.iloc[idx]} \n Prediction: {bnb_predicted[idx]}\n')

# %%
# print('False Negatives:')
# for idx in fn_idx_samps:
#     print(f'Quote: {X_test.iloc[idx]}\n Label: {y_test.iloc[idx]}\n Prediction: {bnb_predicted[idx]}\n')

# %%
# str(text_humor).lower().count('call')

# %%
# str(text_serious).lower().count('photo')

# %% [markdown]
# ## Random Forest

# %%
# rf_pipeline = Pipeline([('tfidf', TfidfVectorizer(max_features=1000)),
#                         ('model', RandomForestClassifier(n_estimators=1000, max_depth=10, verbose=2))])
# rf_pipeline.fit(X_train, y_train)
# rf_predicted = rf_pipeline.predict(X_test)

# %%
# print("\nThe accuracy on the test set is {0:0.3f}.".format(accuracy_score(y_test, rf_predicted)))
# print("\nThe precision on the test set is {0:0.3f}.".format(precision_score(y_test, rf_predicted)))
# print("\nThe recall on the test set is {0:0.3f}.".format(recall_score(y_test, rf_predicted)))

# %%
# rf_pipeline = Pipeline([('tfidf', TfidfVectorizer(max_features=None)),
#                         ('model', RandomForestClassifier(n_estimators=5000, max_leaf_nodes=16, verbose=2))])
# rf_pipeline.fit(X_train, y_train)
# rf_predicted = rf_pipeline.predict(X_test)

# %%
# print("\nThe accuracy on the test set is {0:0.3f}.".format(accuracy_score(y_test, rf_predicted)))
# print("\nThe precision on the test set is {0:0.3f}.".format(precision_score(y_test, rf_predicted)))
# print("\nThe recall on the test set is {0:0.3f}.".format(recall_score(y_test, rf_predicted)))

# %%
# num_trees = [100, 1000, 2000, 5000, 10000]
# accuracies = []

# for n in num_trees:
#     rf_pipeline = Pipeline([('tfidf', TfidfVectorizer(max_features=2000)),
#                         ('model', RandomForestClassifier(n_estimators=n, 
#                                                          max_leaf_nodes=16, 
#                                                          verbose=2))])

#     rf_pipeline.fit(X_train, y_train)
#     rf_predicted = rf_pipeline.predict(X_test)
#     accuracies.append(accuracy_score(y_test, rf_predicted))

# %%
# fig, ax = plt.subplots()
# ax.plot(num_trees, accuracies)
# ax.set_title('RF Accuracy by Number of Trees')
# ax.set_xlabel('num trees')
# ax.set_ylabel('accuracy');

# %%
# num_features = [100, 1000, 2000, 5000, 10000]
# accuracies = []

# for n in num_features:
#     rf_pipeline = Pipeline([('tfidf', TfidfVectorizer(max_features=n)),
#                         ('model', RandomForestClassifier(n_estimators=1000, 
#                                                          max_leaf_nodes=16, 
#                                                          verbose=2))])

#     rf_pipeline.fit(X_train, y_train)
#     rf_predicted = rf_pipeline.predict(X_test)
#     accuracies.append(accuracy_score(y_test, rf_predicted))

# %%
# fig, ax = plt.subplots()
# ax.plot(num_features, accuracies)
# ax.set_title('RF Accuracy by Max Features')
# ax.set_xlabel('num features')
# ax.set_ylabel('accuracy');

# %%
# num_leaf_nodes = [8, 16, 32, 64]
# accuracies = []

# for n in num_leaf_nodes:
#     rf_pipeline = Pipeline([('tfidf', TfidfVectorizer(max_features=None)),
#                         ('model', RandomForestClassifier(n_estimators=1000, 
#                                                          max_leaf_nodes=n, 
#                                                          verbose=2))])

#     rf_pipeline.fit(X_train, y_train)
#     rf_predicted = rf_pipeline.predict(X_test)
#     accuracies.append(accuracy_score(y_test, rf_predicted))

# %%
# fig, ax = plt.subplots()
# ax.plot(num_leaf_nodes, accuracies)
# ax.set_title('RF Accuracy by Max Leaf Nodes')
# ax.set_xlabel('max leaf nodes')
# ax.set_ylabel('accuracy');

# %%
# max_depths = [8, 16, 32, 64]
# accuracies = []

# for n in max_depths:
#     rf_pipeline = Pipeline([('tfidf', TfidfVectorizer(max_features=None)),
#                         ('model', RandomForestClassifier(n_estimators=1000, 
#                                                          max_depth=n, 
#                                                          verbose=2))])

#     rf_pipeline.fit(X_train, y_train)
#     rf_predicted = rf_pipeline.predict(X_test)
#     accuracies.append(accuracy_score(y_test, rf_predicted))

# %%
# fig, ax = plt.subplots()
# ax.plot(max_depths, accuracies)
# ax.set_title('RF Accuracy by Max Depth')
# ax.set_xlabel('max depth')
# ax.set_ylabel('accuracy');

# %%
# n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# max_features = ['auto']
# max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]

# %%
# random_grid = {'n_estimators': n_estimators,
#                'max_features': max_features,
#                'max_depth': max_depth}

# pprint(random_grid)

# %%
# tfid = TfidfVectorizer()
# X_train_tfid = tfid.fit_transform(X_train)

# rf = RandomForestClassifier()
# rf_random = RandomizedSearchCV(estimator = rf, 
#                                param_distributions = random_grid, 
#                                n_iter = 3, 
#                                cv = 3, 
#                                verbose = 2, 
#                                n_jobs = -1)
# rf_random.fit(X_train_tfid, y_train)
# rf_random.best_params_

# %%
rf_pipeline = Pipeline([('tfidf', TfidfVectorizer(max_features=10000)),
                        ('model', RandomForestClassifier(n_estimators=1600, 
                                                         max_depth=90))])
rf_pipeline.fit(X_train, y_train)
rf_predicted = rf_pipeline.predict(X_test)

# %%
print("\nThe accuracy on the test set is {0:0.3f}.".format(accuracy_score(y_test, rf_predicted)))
print("\nThe precision on the test set is {0:0.3f}.".format(precision_score(y_test, rf_predicted)))
print("\nThe recall on the test set is {0:0.3f}.".format(recall_score(y_test, rf_predicted)))
# Out:
# The accuracy on the test set is 0.904.
#
# The precision on the test set is 0.903.
#
# The recall on the test set is 0.904.

# %%
rf_predicted_new = rf_pipeline.predict(X_test_new)

# %%
fig, ax = plt.subplots(figsize=(6,6))
create_confusion_matrix(y_test_new, rf_predicted_new, y_test_new.unique(), ax=ax)
ax.set_xlabel('Actual Labels', fontsize=18)
ax.set_ylabel('Predicted Labels', fontsize=18)
ax.set_title('Random Forest', fontsize=20);

# %%
probs_rf = rf_pipeline.predict_proba(X_test)[:, 1]
fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test_values, probs_rf)

x = np.linspace(0, 1)

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(fpr_rf, tpr_rf, label='Random Forest')
ax.plot(x, x, color='black', linestyle='--')
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Plot')
ax.legend();

# %%
score = roc_auc_score(y_test, probs_rf)
print("The ROC AUC score for the model is {0:0.3f}.".format(score))
# Out:
# The ROC AUC score for the model is 0.968.

# %% [markdown]
# ## MLP

# %%
mlp_pipeline = Pipeline([('tfidf', TfidfVectorizer(max_features=5000)), #10000 = 0.926, #5000 = 0.926, #1000 = 0.91
                        ('model', MLPClassifier(batch_size=32,
                                                hidden_layer_sizes=(32,),
                                                verbose=True,
                                                early_stopping=True))])

# %%
mlp_predicted = fit_predict_model_accuracy(mlp_pipeline, X_train, y_train, X_test, y_test)
# Out:
# Iteration 1, loss = 0.24143404
# Validation score: 0.916267
# Iteration 2, loss = 0.19408305
# Validation score: 0.916733
# Iteration 3, loss = 0.18382456
# Validation score: 0.918800
# Iteration 4, loss = 0.17403181
# Validation score: 0.921133
# Iteration 5, loss = 0.16421712
# Validation score: 0.922467
# Iteration 6, loss = 0.15390629
# Validation score: 0.922533
# Iteration 7, loss = 0.14281555
# Validation score: 0.924267
# Iteration 8, loss = 0.13170774
# Validation score: 0.924667
# Iteration 9, loss = 0.12037313
# Validation score: 0.924733
# Iteration 10, loss = 0.10930443
# Validation score: 0.925933
# Iteration 11, loss = 0.09838682
# Validation score: 0.924667
# Iteration 12, loss = 0.08846477
# Validation score: 0.924667
# Iteration 13, loss = 0.07864227
# Validation score: 0.924067
# Iteration 14, loss = 0.06961798
# Validation score: 0.922733
# Iteration 15, loss = 0.06138979
# Validation score: 0.924467
# Iteration 16, loss = 0.05454384
# Validation score: 0.922467
# Iteration 17, loss = 0.04808168
# Validation score: 0.922667
# Iteration 18, loss = 0.04264200
# Validation score: 0.921733
# Iteration 19, loss = 0.03819590
# Validation score: 0.921533
# Iteration 20, loss = 0.03442190
# Validation score: 0.922733
# Iteration 21, loss = 0.03141141
# Validation score: 0.921667
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#
# The accuracy on the test set is 0.925.

# %%
print("\nThe accuracy on the test set is {0:0.3f}.".format(accuracy_score(y_test, mlp_predicted)))
print("\nThe precision on the test set is {0:0.3f}.".format(precision_score(y_test, mlp_predicted)))
print("\nThe recall on the test set is {0:0.3f}.".format(recall_score(y_test, mlp_predicted)))
# Out:
# The accuracy on the test set is 0.925.
#
# The precision on the test set is 0.926.
#
# The recall on the test set is 0.924.

# %%
get_multiple_predictions(text_list=text_list, label_list=label_list, pipeline=mlp_pipeline)
# Out:
# Text: When the prosecuting attorney asked Gucci Mane if he was guilty he said, 'bitch I might be.'
# Prediction: Humorous
# Label: Humorous
#
# Text: Camus says that when you wish yourself into the future you commit suicide by wishing yourself closer to your death.
# Prediction: Serious
# Label: Serious
#
# Text: How did the random variable get into the club? By showing a fake i.i.d.
# Prediction: Humorous
# Label: Humorous
#
# Text: Laugh it up! Humor is universal across human cultures — and fuels psychological research on everything from social perception to emotion
# Prediction: Humorous
# Label: Serious
#
# Text: Saddest 6 word story: "Soup of the Day: No Soup."
# Prediction: Serious
# Label: Humorous
#
# Text: My mom always told me I wouldn’t accomplish anything by lying in bed all day. But look at me now, ma! I’m saving the world!
# Prediction: Humorous
# Label: Humorous
#
# Text: If I keep stress-eating at this level, the buttons on my shirt will start socially distancing from each other.
# Prediction: Humorous
# Label: Humorous
#
# Text: To help prevent the spread of COVID-19, everyone should wear a mask in public.
# Prediction: Serious
# Label: Serious
#
# Text: Avoid close contact with people who are sick.
# Prediction: Humorous
# Label: Serious
#
# Text: What did one support vector say to another support vector? I feel so marginalized.
# Prediction: Humorous
# Label: Humorous

# %%
mlp_predicted_new = mlp_pipeline.predict(X_test_new)

# %%
fig, ax = plt.subplots(figsize=(6,6))
create_confusion_matrix(y_test_new, mlp_predicted_new, y_test_new.unique(), ax=ax)
ax.set_xlabel('Actual Labels', fontsize=18)
ax.set_ylabel('Predicted Labels', fontsize=18)
ax.set_title('Mulilayer Perceptron', fontsize=20);

# %%
probs_mlp = mlp_pipeline.predict_proba(X_test)[:, 1]
fpr_mlp, tpr_mlp, thresholds_mlp = roc_curve(y_test_values, probs_mlp)

x = np.linspace(0, 1)

fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(fpr_mlp, tpr_mlp, label='MLP')
ax.plot(x, x, color='black', linestyle='--')
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Plot')
ax.legend();

# %%
score = roc_auc_score(y_test, probs_mlp)
print("The ROC AUC score for the model is {0:0.3f}.".format(score))
# Out:
# The ROC AUC score for the model is 0.979.

# %% [markdown]
# ## Combined ROC

# %%
# mnb_probs = mnb_pipeline.predict_proba(X_test)[:, 1]
# mnb_fpr, mnb_tpr, mnb_thresholds = roc_curve(y_test_values, mnb_probs)

# %%
# bnb_probs = bnb_pipeline.predict_proba(X_test)[:, 1]
# bnb_fpr, bnb_tpr, bnb_thresholds = roc_curve(y_test_values, bnb_probs)

# %%
# probs_rf = rf_pipeline.predict_proba(X_test)[:, 1]
# fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test_values, probs_rf)

# %%
# probs_mlp = mlp_pipeline.predict_proba(X_test)[:, 1]
# fpr_mlp, tpr_mlp, thresholds_mlp = roc_curve(y_test_values, probs_mlp)

# %%
x = np.linspace(0, 1)

plt.style.use('default')

fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(fpr_mlp, tpr_mlp, color = 'blue', label='Multilayer Perceptron')
ax.plot(bnb_fpr, bnb_tpr, color = 'red', label='Bernoulli Naive Bayes')
ax.plot(mnb_fpr, mnb_tpr, color ='purple', linestyle='--', label='Multinomial Naive Bayes')
ax.plot(fpr_rf, tpr_rf, color='orange', label='Random Forest')
ax.plot(x, x, color='black', linestyle='-.')
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Plot')
ax.legend(loc='lower right');

plt.savefig('Combined_ROC.png')

# %%
probs = [mnb_probs, bnb_probs, probs_rf, probs_mlp]
titles = ['Multinomial Naive Bayes', 'Bernoulli Naive Bayes', 'Random Forest', 'Multilayer Perceptron']
scores = []

for idx, prob in enumerate(probs):
    score = roc_auc_score(y_test, prob)
    scores.append(score)
    print(f'\nModel: {titles[idx]}')
    print("The ROC AUC score for the model is {0:0.3f}.".format(score))

print(f'\nThe model with the largest AUC: {titles[int(np.where(scores == np.max(scores))[0])]}')
# Out:
# Model: Multinomial Naive Bayes
# The ROC AUC score for the model is 0.975.
#
# Model: Bernoulli Naive Bayes
# The ROC AUC score for the model is 0.977.
#
# Model: Random Forest
# The ROC AUC score for the model is 0.968.
#
# Model: Multilayer Perceptron
# The ROC AUC score for the model is 0.979.
#
# The model with the largest AUC: Multilayer Perceptron

# %% [markdown]
# ## What texts does the best model have trouble with?

# %%
def get_misclassified_corpus(X_test, y_test, predicted):
    
    misclass = np.where((y_test != predicted))[0]
    misclass_idx = list(misclass)
    misclass_corpus = []
    for idx in misclass_idx:
        misclass_corpus.append(X_test.iloc[idx])

    fp = np.where((y_test == False) & (predicted == True))[0]
    fp_idx = list(fp)
    fp_corpus = []
    for idx in fp_idx:
        fp_corpus.append(X_test.iloc[idx])
    
    fn = np.where((y_test == True) & (predicted == False))[0]
    fn_idx = list(fn)
    fn_corpus = []
    for idx in fn_idx:
        fn_corpus.append(X_test.iloc[idx])
            
    return misclass_corpus, fp_corpus, fn_corpus

# %%
misclass_corpus, fp_corpus, fn_corpus = get_misclassified_corpus(X_test, y_test, mlp_predicted)

# %%
wc_misclass = WordCloud(colormap="cool", relative_scaling=1, max_words=None, max_font_size=40)
word_cloud_misclass = make_word_cloud(misclass_corpus, wc_misclass)

wc_fp = WordCloud(colormap="cool", relative_scaling=1, max_words=None, max_font_size=40)
word_cloud_fp = make_word_cloud(fp_corpus, wc_fp)

wc_fn = WordCloud(colormap="cool", relative_scaling=1, max_words=None, max_font_size=40)
word_cloud_fn = make_word_cloud(fn_corpus, wc_fn)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.imshow(word_cloud_misclass, interpolation = 'bilinear')
ax.set_axis_off()
ax.set_title('Top Words in Misclassified Texts');

#plt.savefig('misclass_wc.png')

# %%
# fig, axs = plt.subplots(3, 1, figsize=(10,10))
# wordclouds = [word_cloud_misclass, word_cloud_fp, word_cloud_fn]
# titles = ['Top Words in Misclassified Texts', 'Top Mistakenly Humorous Words - False Positives', 'Top Mistakenly Serious Words - False Negatives']

# i = 0
# for wordcloud, ax in zip(wordclouds, axs.flatten()):
#     ax.imshow(wordcloud, interpolation = 'bilinear')
#     ax.set_axis_off()
#     ax.set_title(titles[i])
#     i += 1
# fig.tight_layout()

# %%
get_top_words(word_cloud_misclass, num_words=10)
# Out:
# 'The top 10 words are: make, want, peopl, one, say, go, new, time, kid, day'

# %% [markdown]
# ## KMeans Clustering

# %%
k = 2
vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
X_vec = vectorizer.fit_transform(X)
features = vectorizer.get_feature_names()
kmeans = KMeans(n_clusters=k, verbose=2)
kmeans.fit(X_vec)
# Out:
# Initialization complete
# Iteration 0, inertia 388149.1923786895
# Iteration 1, inertia 191639.83093338553
# Iteration 2, inertia 191579.34586228427
# Iteration 3, inertia 191571.32482921568
# Iteration 4, inertia 191571.321796483
# Converged at iteration 4: center shift 1.3816486241020395e-34 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 389157.41278499516
# Iteration 1, inertia 192281.13332717467
# Iteration 2, inertia 191630.92292303414
# Iteration 3, inertia 191591.89389738793
# Iteration 4, inertia 191591.89142576692
# Converged at iteration 4: center shift 0.0 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 386620.7441931095
# Iteration 1, inertia 191247.9430580422
# Iteration 2, inertia 191016.14089755775
# Iteration 3, inertia 190970.47967394395
# Iteration 4, inertia 190970.1624471822
# Iteration 5, inertia 190970.10227877583
# Iteration 6, inertia 190970.09539334147
# Converged at iteration 6: center shift 9.36338254966766e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 388851.7392663756
# Iteration 1, inertia 191924.79623603754
# Iteration 2, inertia 191859.193458793
# Iteration 3, inertia 191829.08537511728
# Iteration 4, inertia 191829.0841242776
# Converged at iteration 4: center shift 1.4968745063371011e-34 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 388834.94519931905
# Iteration 1, inertia 192332.21292867998
# Iteration 2, inertia 191767.08061105225
# Iteration 3, inertia 191656.68474233398
# Iteration 4, inertia 191563.42268385587
# Iteration 5, inertia 191515.22318671521
# Iteration 6, inertia 191513.62674970718
# Iteration 7, inertia 191512.57126531383
# Iteration 8, inertia 191510.90220713668
# Iteration 9, inertia 191505.1985456332
# Iteration 10, inertia 191486.16231994325
# Iteration 11, inertia 191455.14647097146
# Iteration 12, inertia 191451.30548189845
# Iteration 13, inertia 191451.27179166043
# Iteration 14, inertia 191451.26531392656
# Iteration 15, inertia 191451.26274730163
# Converged at iteration 15: center shift 2.2216364013148673e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 384394.28950701456
# Iteration 1, inertia 191371.4947450304
# Iteration 2, inertia 191306.27933080788
# Iteration 3, inertia 191222.363349503
# Iteration 4, inertia 191197.52670979596
# Iteration 5, inertia 191197.51733215287
# Converged at iteration 5: center shift 0.0 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 390217.65717004513
# Iteration 1, inertia 192384.90920979957
# Iteration 2, inertia 191940.71653564862
# Iteration 3, inertia 191824.65005092017
# Iteration 4, inertia 191800.1744222328
# Iteration 5, inertia 191783.19802542744
# Iteration 6, inertia 191763.32170822218
# Iteration 7, inertia 191752.8194933245
# Iteration 8, inertia 191750.8338666958
# Iteration 9, inertia 191745.84462192983
# Iteration 10, inertia 191723.778589553
# Iteration 11, inertia 191685.00282165568
# Iteration 12, inertia 191680.33253571618
# Iteration 13, inertia 191678.11957950817
# Iteration 14, inertia 191672.0273666951
# Iteration 15, inertia 191652.66828003823
# Iteration 16, inertia 191607.4697897011
# Iteration 17, inertia 191583.1626995389
# Iteration 18, inertia 191581.961536578
# Converged at iteration 18: center shift 6.954505876332296e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 388620.9258712433
# Iteration 1, inertia 192372.241457145
# Iteration 2, inertia 192368.1624793826
# Iteration 3, inertia 192350.73050014288
# Iteration 4, inertia 192343.6913278329
# Iteration 5, inertia 192343.6898809938
# Converged at iteration 5: center shift 1.2417475634233333e-32 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 388768.976550455
# Iteration 1, inertia 192380.75126700854
# Iteration 2, inertia 192007.7552121536
# Iteration 3, inertia 191923.1639174005
# Iteration 4, inertia 191842.70525731088
# Iteration 5, inertia 191774.96546417216
# Iteration 6, inertia 191720.40991832694
# Iteration 7, inertia 191662.3861253361
# Iteration 8, inertia 191620.18234823758
# Iteration 9, inertia 191603.1086584719
# Iteration 10, inertia 191592.85555056875
# Iteration 11, inertia 191579.46714637414
# Iteration 12, inertia 191571.75198222316
# Iteration 13, inertia 191570.79200421754
# Iteration 14, inertia 191570.76814124337
# Iteration 15, inertia 191570.75869274713
# Converged at iteration 15: center shift 4.384081076540857e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 193675.04646136358
# Iteration 1, inertia 192389.73110534347
# Iteration 2, inertia 192338.64674569585
# Iteration 3, inertia 192336.2602784866
# Iteration 4, inertia 192336.12317411453
# Iteration 5, inertia 192336.12156369907
# Converged at iteration 5: center shift 0.0 within tolerance 9.62771570643571e-08
# KMeans(n_clusters=2, verbose=2)

# %%
print(kmeans.cluster_centers_)
# Out:
# [[0.00179168 0.00516285 0.0015433  ... 0.00088422 0.0021788  0.00150179]
#  [0.00023603 0.00227284 0.00068274 ... 0.0002579  0.00042464 0.00082371]]

# %%
# Find the top 10 features for each cluster.
n_features = 10
top_centroids = kmeans.cluster_centers_.argsort()[:,-1:-(n_features+1):-1]
print("top features (words) for each cluster:")
for num, centroid in enumerate(top_centroids):
    print(f"{num}, {', '.join(features[i] for i in centroid)}")
# Out:
# top features (words) for each cluster:
# 0, like, trump, new, just, people, does, don, photos, make, know
# 1, did, say, hear, cross, road, got, man, chicken, know, guy

# %%
print("Random sample of texts in each cluster \n")
assigned_cluster = kmeans.transform(X_vec).argmin(axis=1)
for i in range(kmeans.n_clusters):
    cluster = np.arange(0, X_vec.shape[0])[assigned_cluster==i]
    sample_texts = np.random.choice(cluster, 10, replace=False)
    
    print(f'\n cluster {i}:')
    for idx in sample_texts:
        print(f'Quote: {X.iloc[idx]}\n Label: {y.iloc[idx]}')
# Out:
# Random sample of texts in each cluster
#
#
#  cluster 0:
# Quote: Yo mama so fat... yo mama so fat , you can see what's behind her !
#  Label: True
# Quote: If love is blind why is lingerie so  popular?
#  Label: True
# Quote: What's a monster's favorite bean? a human bean.
#  Label: True
# Quote: Cheese shop exploded thankfully i was only hit by da brie
#  Label: True
# Quote: Stephanie gilmore's espy awards fashion is spot on (photos)
#  Label: False
# Quote: Why the 2-million pound ready-to-eat chicken recall is extra risky
#  Label: False
# Quote: Worrying is so stupid. it's like carrying an umbrella waiting for it to rain.
#  Label: True
# Quote: Watertown perspective: the boston marathon suspect manhunt on friday
#  Label: False
# Quote: The best place to get fit (hint: it's free)
#  Label: False
# Quote: Painting found in french attic is $137 million caravaggio, say experts
#  Label: False
#
#  cluster 1:
# Quote: Did you hear about the new emo website? www.emo.com/wrists
#  Label: True
# Quote: What did the corn stalk say to the other corn stalk? that outfit makes you look very corny.
#  Label: True
# Quote: What did the host say after her guest complimented her on her tea? thanks, it's my special tea.
#  Label: True
# Quote: Why did the cat get arrested for playing a violin? because it was a kitty fiddler.
#  Label: True
# Quote: How did moses make his tea? hebrews it
#  Label: True
# Quote: Why did the elephant sit on the marshmallow? because it didnt want to swim in the hot chocolate
#  Label: True
# Quote: What did goku want to be when he was growing up? a saiyantist!
#  Label: True
# Quote: Why did saddam hussein never have sex? ....because he was afraid he'd see bush.
#  Label: True
# Quote: Carly fiorina did great on stage. not so much online.
#  Label: False
# Quote: What did the pilot say when his plane wasn't flying? aw man, that's a drag.
#  Label: True

# %%
for i in range(kmeans.n_clusters):
    cluster = np.arange(0, X_vec.shape[0])[assigned_cluster==i]
    categories = y.iloc[cluster]
    most_common = Counter(categories).most_common()
    print(f"Cluster {i}:")
    for j in range (len(most_common)):
        print(f"     {most_common[j][0]} ({most_common[j][1]} texts)")
# Out:
# Cluster 0:
#      False (99587 texts)
#      True (90012 texts)
# Cluster 1:
#      True (9988 texts)
#      False (413 texts)

# %%
range_n_clusters = range(2,10)

# taken from sklearn
for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, ax1 = plt.subplots()
    #fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, X_vec.shape[0] + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, verbose=2, random_state=10)
    cluster_labels = clusterer.fit_predict(X_vec)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X_vec, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X_vec, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i
        
        cmap = cm.get_cmap('Spectral')
        color = cmap(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhoutte score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

#     # 2nd Plot showing the actual clusters formed

#     colors = cmap(cluster_labels.astype(float) / n_clusters)
#     ax2.scatter(X[:, 0], X[:, 1], marker='.', s=30, lw=0, alpha=0.7,
#                 c=colors)

#     # Labeling the clusters
#     centers = clusterer.cluster_centers_
#     # Draw white circles at cluster centers
#     ax2.scatter(centers[:, 0], centers[:, 1],
#                 marker='o', c="white", alpha=1, s=200)

#     for i, c in enumerate(centers):
#         ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1, s=50)

#     ax2.set_title("The visualization of the clustered data.")
#     ax2.set_xlabel("Feature space for the 1st feature")
#     ax2.set_ylabel("Feature space for the 2nd feature")

#     plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
#                   "with n_clusters = %d" % n_clusters),
#                  fontsize=14, fontweight='bold')

#     plt.show()
# Out:
# Initialization complete
# Iteration 0, inertia 391663.7186153257
# Iteration 1, inertia 192446.68253863548
# Iteration 2, inertia 191831.0047963292
# Iteration 3, inertia 191662.40935891971
# Iteration 4, inertia 191566.34198131852
# Iteration 5, inertia 191542.92592954455
# Iteration 6, inertia 191538.76089908314
# Iteration 7, inertia 191535.09627734005
# Iteration 8, inertia 191527.86815429118
# Iteration 9, inertia 191522.50793716704
# Iteration 10, inertia 191521.92550169546
# Iteration 11, inertia 191521.9064424729
# Iteration 12, inertia 191521.89210512684
# Iteration 13, inertia 191521.873112058
# Iteration 14, inertia 191521.86172917887
# Iteration 15, inertia 191521.8462012117
# Iteration 16, inertia 191521.83218810437
# Iteration 17, inertia 191521.82410405492
# Converged at iteration 17: center shift 3.4219812169005815e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 386055.2612014247
# Iteration 1, inertia 192167.7820566593
# Iteration 2, inertia 191545.35495950683
# Iteration 3, inertia 191455.28039101866
# Iteration 4, inertia 191418.3073703326
# Iteration 5, inertia 191380.495419827
# Iteration 6, inertia 191370.85629330133
# Iteration 7, inertia 191370.80485819964
# Iteration 8, inertia 191370.79678314668
# Converged at iteration 8: center shift 5.203223714059945e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 389023.63824208366
# Iteration 1, inertia 192061.38674677204
# Iteration 2, inertia 192040.3364461539
# Iteration 3, inertia 192039.68362118848
# Iteration 4, inertia 192039.543965716
# Iteration 5, inertia 192039.49618284154
# Iteration 6, inertia 192039.4836325118
# Iteration 7, inertia 192039.47952321277
# Iteration 8, inertia 192039.47562727827
# Iteration 9, inertia 192039.47506882652
# Converged at iteration 9: center shift 3.5527259638489705e-34 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 385572.8926642241
# Iteration 1, inertia 191392.0938530912
# Iteration 2, inertia 191349.43699538778
# Iteration 3, inertia 191348.57356568973
# Iteration 4, inertia 191348.29930443974
# Iteration 5, inertia 191348.1488904728
# Iteration 6, inertia 191348.05052780488
# Iteration 7, inertia 191347.97636251926
# Iteration 8, inertia 191347.91517303308
# Iteration 9, inertia 191347.8499864312
# Iteration 10, inertia 191347.787038899
# Iteration 11, inertia 191347.7152577681
# Iteration 12, inertia 191347.53867680737
# Iteration 13, inertia 191347.29958664635
# Iteration 14, inertia 191346.94289271446
# Iteration 15, inertia 191346.25213214688
# Iteration 16, inertia 191344.52617433932
# Iteration 17, inertia 191339.5996213236
# Iteration 18, inertia 191323.26288783812
# Iteration 19, inertia 191267.24697890168
# Iteration 20, inertia 191204.11042659002
# Iteration 21, inertia 191197.52053802458
# Iteration 22, inertia 191197.51733215287
# Converged at iteration 22: center shift 0.0 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 384593.9646230704
# Iteration 1, inertia 191837.25700372146
# Iteration 2, inertia 191823.23277977624
# Iteration 3, inertia 191823.12289442454
# Converged at iteration 3: center shift 4.288998638651985e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 390978.33501143026
# Iteration 1, inertia 192331.15459262193
# Iteration 2, inertia 192320.50701133357
# Iteration 3, inertia 192314.11880961506
# Iteration 4, inertia 192310.54323255416
# Iteration 5, inertia 192301.3557718388
# Iteration 6, inertia 192299.10953841868
# Iteration 7, inertia 192298.05186163555
# Iteration 8, inertia 192293.2726814398
# Iteration 9, inertia 192280.30284646078
# Iteration 10, inertia 192276.76143834318
# Converged at iteration 10: center shift 1.0079864130047597e-34 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 388373.87652527384
# Iteration 1, inertia 192107.23435528387
# Iteration 2, inertia 192107.22491651858
# Iteration 3, inertia 192107.2242681497
# Converged at iteration 3: center shift 3.292838523614046e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 391390.65405581344
# Iteration 1, inertia 192455.79069215377
# Iteration 2, inertia 191963.73077866196
# Iteration 3, inertia 191790.3643569982
# Iteration 4, inertia 191702.4503967331
# Iteration 5, inertia 191642.05095413147
# Iteration 6, inertia 191593.5250277112
# Iteration 7, inertia 191527.55703995176
# Iteration 8, inertia 191492.41684162422
# Iteration 9, inertia 191489.60864736114
# Iteration 10, inertia 191486.83576553618
# Iteration 11, inertia 191480.47777400856
# Iteration 12, inertia 191463.97350973284
# Iteration 13, inertia 191449.97933162746
# Iteration 14, inertia 191448.7034069623
# Iteration 15, inertia 191448.64827259033
# Iteration 16, inertia 191448.59426435965
# Iteration 17, inertia 191448.55469438006
# Iteration 18, inertia 191448.5330704671
# Iteration 19, inertia 191448.514925716
# Iteration 20, inertia 191448.49990476112
# Iteration 21, inertia 191448.47505863776
# Iteration 22, inertia 191448.43503868257
# Iteration 23, inertia 191448.39015888507
# Iteration 24, inertia 191448.30539808059
# Iteration 25, inertia 191448.14297489403
# Iteration 26, inertia 191447.70774389143
# Iteration 27, inertia 191446.55285487854
# Iteration 28, inertia 191443.01976499584
# Iteration 29, inertia 191426.0547184094
# Iteration 30, inertia 191368.59189414934
# Iteration 31, inertia 191330.49912730276
# Iteration 32, inertia 191329.00843571563
# Iteration 33, inertia 191328.99493695446
# Converged at iteration 33: center shift 6.524293801721897e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 388329.73862639704
# Iteration 1, inertia 192287.39041702804
# Iteration 2, inertia 192287.38599227899
# Converged at iteration 2: center shift 3.222253359530546e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 385849.86626717873
# Iteration 1, inertia 192378.92688724425
# Iteration 2, inertia 191638.58590353723
# Iteration 3, inertia 191457.48474328272
# Iteration 4, inertia 191347.27617942728
# Iteration 5, inertia 191262.1393165161
# Iteration 6, inertia 191230.30733034603
# Iteration 7, inertia 191208.7370809341
# Iteration 8, inertia 191152.4540260259
# Iteration 9, inertia 191122.00147160096
# Iteration 10, inertia 191119.41539170465
# Iteration 11, inertia 191117.52213718588
# Iteration 12, inertia 191116.18218464684
# Iteration 13, inertia 191115.8629376467
# Iteration 14, inertia 191115.73613217525
# Iteration 15, inertia 191115.6792993362
# Iteration 16, inertia 191115.629574907
# Iteration 17, inertia 191115.61162759556
# Iteration 18, inertia 191115.60575349952
# Converged at iteration 18: center shift 9.466495966560641e-08 within tolerance 9.62771570643571e-08
# For n_clusters = 2 The average silhouette_score is : 0.013960336878571943
# Initialization complete
# Iteration 0, inertia 193694.6467064494
# Iteration 1, inertia 192375.18020111212
# Iteration 2, inertia 191878.01323041302
# Iteration 3, inertia 191509.48956458026
# Iteration 4, inertia 191495.6052073374
# Iteration 5, inertia 191495.5550996929
# Iteration 6, inertia 191495.55427276462
# Converged at iteration 6: center shift 3.3785999856616646e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 381964.6699380699
# Iteration 1, inertia 191083.76975453066
# Iteration 2, inertia 190628.59356349288
# Iteration 3, inertia 190568.04419262856
# Iteration 4, inertia 190534.4123985432
# Iteration 5, inertia 190497.68522200148
# Iteration 6, inertia 190475.6757494877
# Iteration 7, inertia 190414.85231716465
# Iteration 8, inertia 190260.23816602564
# Iteration 9, inertia 190204.95321674028
# Iteration 10, inertia 190201.73497299972
# Iteration 11, inertia 190199.73852866658
# Iteration 12, inertia 190198.10857628225
# Iteration 13, inertia 190197.27788642145
# Iteration 14, inertia 190196.91953735435
# Iteration 15, inertia 190196.71220109283
# Iteration 16, inertia 190196.5937765396
# Iteration 17, inertia 190196.4795638272
# Iteration 18, inertia 190196.42836650208
# Iteration 19, inertia 190196.41415542766
# Iteration 20, inertia 190196.41154219006
# Converged at iteration 20: center shift 1.707066439545295e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 381557.1148142536
# Iteration 1, inertia 191117.55697831215
# Iteration 2, inertia 191010.25668238316
# Iteration 3, inertia 190901.26596574823
# Iteration 4, inertia 190689.72094688125
# Iteration 5, inertia 190557.79157450964
# Iteration 6, inertia 190413.781123903
# Iteration 7, inertia 190309.60709759727
# Iteration 8, inertia 190289.21419673236
# Iteration 9, inertia 190289.19770115305
# Converged at iteration 9: center shift 1.655764057356834e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 382051.4465794583
# Iteration 1, inertia 191085.5171695836
# Iteration 2, inertia 190588.61175146984
# Iteration 3, inertia 190546.84433278753
# Iteration 4, inertia 190545.27012619044
# Iteration 5, inertia 190544.09874901178
# Iteration 6, inertia 190542.19847055568
# Iteration 7, inertia 190536.79619206281
# Iteration 8, inertia 190515.70895621376
# Iteration 9, inertia 190445.02274097517
# Iteration 10, inertia 190409.40515656906
# Iteration 11, inertia 190409.35795449515
# Iteration 12, inertia 190409.2940637901
# Iteration 13, inertia 190409.13450071105
# Iteration 14, inertia 190408.90424712579
# Iteration 15, inertia 190408.6110065601
# Iteration 16, inertia 190408.0333186522
# Iteration 17, inertia 190406.60201064192
# Iteration 18, inertia 190402.62801618144
# Iteration 19, inertia 190389.30059774444
# Iteration 20, inertia 190339.7059506098
# Iteration 21, inertia 190269.39556700474
# Iteration 22, inertia 190259.9561411214
# Iteration 23, inertia 190259.95288880446
# Converged at iteration 23: center shift 1.9165039490615796e-34 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 382497.5097601561
# Iteration 1, inertia 191134.5689547561
# Iteration 2, inertia 191103.00431197393
# Iteration 3, inertia 191102.84987145787
# Converged at iteration 3: center shift 5.827415107498249e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 386962.8555295073
# Iteration 1, inertia 192154.46688557538
# Iteration 2, inertia 191770.046562479
# Iteration 3, inertia 191680.77118626813
# Iteration 4, inertia 191592.77698984562
# Iteration 5, inertia 191517.30986051643
# Iteration 6, inertia 191469.30032633842
# Iteration 7, inertia 191412.71074088916
# Iteration 8, inertia 191355.86345425196
# Iteration 9, inertia 191334.96082367603
# Iteration 10, inertia 191326.11676071442
# Iteration 11, inertia 191313.6909382584
# Iteration 12, inertia 191303.31006642611
# Iteration 13, inertia 191301.8169974686
# Iteration 14, inertia 191301.79412868113
# Converged at iteration 14: center shift 9.190757107723646e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 385386.30675624585
# Iteration 1, inertia 191285.5149550177
# Iteration 2, inertia 191187.45682360066
# Iteration 3, inertia 191186.36160127787
# Iteration 4, inertia 191186.36021665894
# Converged at iteration 4: center shift 1.3282351480322582e-32 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 386232.0130538894
# Iteration 1, inertia 191027.7770210845
# Iteration 2, inertia 190150.2785799592
# Iteration 3, inertia 190057.0855697655
# Iteration 4, inertia 190044.3545894845
# Iteration 5, inertia 190035.0245351883
# Iteration 6, inertia 190029.21236045283
# Iteration 7, inertia 190026.90931922186
# Iteration 8, inertia 190026.2435956854
# Iteration 9, inertia 190026.11027637112
# Iteration 10, inertia 190026.08117974794
# Iteration 11, inertia 190026.07777655448
# Converged at iteration 11: center shift 1.8582747343676437e-34 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 385246.19859891647
# Iteration 1, inertia 191311.16332928004
# Iteration 2, inertia 191212.06628954172
# Iteration 3, inertia 191151.46749971784
# Iteration 4, inertia 191087.2499211206
# Iteration 5, inertia 191084.33757270448
# Iteration 6, inertia 191084.33646566217
# Converged at iteration 6: center shift 1.2399220206965065e-32 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 380358.3058273379
# Iteration 1, inertia 191005.21624310463
# Iteration 2, inertia 190499.75654962208
# Iteration 3, inertia 190362.923206886
# Iteration 4, inertia 190292.92466284463
# Iteration 5, inertia 190249.50521438546
# Iteration 6, inertia 190216.86791757966
# Iteration 7, inertia 190193.5890464013
# Iteration 8, inertia 190182.74193674684
# Iteration 9, inertia 190182.57222447885
# Iteration 10, inertia 190182.34936485748
# Iteration 11, inertia 190182.00041074204
# Iteration 12, inertia 190181.51024286632
# Iteration 13, inertia 190180.09173499304
# Iteration 14, inertia 190175.8086762114
# Iteration 15, inertia 190169.77389474047
# Iteration 16, inertia 190167.61892095284
# Iteration 17, inertia 190167.23945935763
# Converged at iteration 17: center shift 7.011024772171899e-09 within tolerance 9.62771570643571e-08
# For n_clusters = 3 The average silhouette_score is : 0.016064336543313545
# Initialization complete
# Iteration 0, inertia 193508.1898690564
# Iteration 1, inertia 191473.64156032578
# Iteration 2, inertia 190720.6108067089
# Iteration 3, inertia 190271.9148718208
# Iteration 4, inertia 190144.81529410402
# Iteration 5, inertia 189992.90551835604
# Iteration 6, inertia 189953.83196645082
# Iteration 7, inertia 189943.1972381573
# Iteration 8, inertia 189936.73799270883
# Iteration 9, inertia 189933.92160229772
# Iteration 10, inertia 189932.8884690305
# Iteration 11, inertia 189932.73928359704
# Iteration 12, inertia 189932.68908270122
# Iteration 13, inertia 189932.68435068207
# Converged at iteration 13: center shift 2.6671414477048566e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 378652.0714774012
# Iteration 1, inertia 190094.5101745872
# Iteration 2, inertia 189313.13480536037
# Iteration 3, inertia 189046.8342668963
# Iteration 4, inertia 188912.71990669862
# Iteration 5, inertia 188873.25729038837
# Iteration 6, inertia 188866.57264413848
# Iteration 7, inertia 188865.96146835838
# Iteration 8, inertia 188865.08251348903
# Iteration 9, inertia 188863.6366870179
# Iteration 10, inertia 188859.24052455308
# Iteration 11, inertia 188841.03245025457
# Iteration 12, inertia 188782.76527709267
# Iteration 13, inertia 188755.67160097408
# Iteration 14, inertia 188755.1618205818
# Iteration 15, inertia 188755.1540776071
# Converged at iteration 15: center shift 2.4739976684756785e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 379391.4270378811
# Iteration 1, inertia 190332.0094548123
# Iteration 2, inertia 190212.6302923485
# Iteration 3, inertia 190095.78640745845
# Iteration 4, inertia 189889.16097347124
# Iteration 5, inertia 189761.3549542152
# Iteration 6, inertia 189615.6770372751
# Iteration 7, inertia 189514.0081734866
# Iteration 8, inertia 189500.2152832607
# Iteration 9, inertia 189500.16713149482
# Converged at iteration 9: center shift 7.745963422361519e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 378293.7035572919
# Iteration 1, inertia 190237.24008925943
# Iteration 2, inertia 189721.16366403498
# Iteration 3, inertia 189694.4982918625
# Iteration 4, inertia 189685.28902063228
# Iteration 5, inertia 189666.83449089428
# Iteration 6, inertia 189609.66995918835
# Iteration 7, inertia 189475.94962345852
# Iteration 8, inertia 189397.84644111258
# Iteration 9, inertia 189396.1479732299
# Iteration 10, inertia 189396.14732402
# Converged at iteration 10: center shift 4.020518360341953e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 379142.4983243119
# Iteration 1, inertia 190630.12563340078
# Iteration 2, inertia 190532.75369651825
# Iteration 3, inertia 190505.4327347246
# Iteration 4, inertia 190494.9820191279
# Iteration 5, inertia 190453.80511731107
# Iteration 6, inertia 190405.54443742568
# Iteration 7, inertia 190404.89498617538
# Iteration 8, inertia 190404.89430583108
# Converged at iteration 8: center shift 3.403308188149727e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 383127.4715061329
# Iteration 1, inertia 191047.62780446143
# Iteration 2, inertia 190513.37454024734
# Iteration 3, inertia 190409.5164246853
# Iteration 4, inertia 190352.70931395807
# Iteration 5, inertia 190274.27249915816
# Iteration 6, inertia 190197.8458228273
# Iteration 7, inertia 190143.79896149147
# Iteration 8, inertia 190104.0419779782
# Iteration 9, inertia 190073.99185359152
# Iteration 10, inertia 190036.28884462256
# Iteration 11, inertia 190003.7478987699
# Iteration 12, inertia 189991.2956611445
# Iteration 13, inertia 189989.9040961547
# Iteration 14, inertia 189989.46934439059
# Iteration 15, inertia 189988.88726826207
# Iteration 16, inertia 189987.14098869608
# Iteration 17, inertia 189982.9006137509
# Iteration 18, inertia 189973.06828578917
# Iteration 19, inertia 189962.83205777124
# Iteration 20, inertia 189958.19089388486
# Iteration 21, inertia 189958.18390798641
# Converged at iteration 21: center shift 1.4033690826916354e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 382826.2242515492
# Iteration 1, inertia 190946.42648368826
# Iteration 2, inertia 190838.47083890208
# Iteration 3, inertia 190834.84054177752
# Iteration 4, inertia 190834.83781019642
# Converged at iteration 4: center shift 3.5427047725455306e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 383471.7653729123
# Iteration 1, inertia 190878.71623833943
# Iteration 2, inertia 189630.64438013514
# Iteration 3, inertia 189459.73926796834
# Iteration 4, inertia 189432.09599317357
# Iteration 5, inertia 189414.69496697967
# Iteration 6, inertia 189408.6669606867
# Iteration 7, inertia 189402.50845327022
# Iteration 8, inertia 189389.53831370422
# Iteration 9, inertia 189380.096937275
# Iteration 10, inertia 189377.41560984496
# Iteration 11, inertia 189370.80748755627
# Iteration 12, inertia 189347.7761134282
# Iteration 13, inertia 189325.36715493628
# Iteration 14, inertia 189324.9162596857
# Iteration 15, inertia 189324.4507174877
# Iteration 16, inertia 189323.8713441423
# Iteration 17, inertia 189323.1118143891
# Iteration 18, inertia 189321.40297044336
# Iteration 19, inertia 189315.42380509936
# Iteration 20, inertia 189290.63491860186
# Iteration 21, inertia 189238.6612794843
# Iteration 22, inertia 189229.98985308464
# Iteration 23, inertia 189229.98676695026
# Converged at iteration 23: center shift 5.3731936178243585e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 382491.79755582794
# Iteration 1, inertia 190488.7344458578
# Iteration 2, inertia 190292.60751182225
# Iteration 3, inertia 190215.90996537622
# Iteration 4, inertia 190154.06483539703
# Iteration 5, inertia 190151.24818207935
# Iteration 6, inertia 190151.2475673118
# Converged at iteration 6: center shift 1.5738217810906398e-32 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 376642.90070855955
# Iteration 1, inertia 190285.38890663796
# Iteration 2, inertia 189797.26000835557
# Iteration 3, inertia 189672.02954577576
# Iteration 4, inertia 189596.3297697241
# Iteration 5, inertia 189527.26027631492
# Iteration 6, inertia 189438.70564016455
# Iteration 7, inertia 189358.32955210542
# Iteration 8, inertia 189330.38030716582
# Iteration 9, inertia 189316.7823893245
# Iteration 10, inertia 189315.64762816264
# Converged at iteration 10: center shift 8.688900794156185e-08 within tolerance 9.62771570643571e-08
# For n_clusters = 4 The average silhouette_score is : 0.018571880881371027
# Initialization complete
# Iteration 0, inertia 193446.47468077834
# Iteration 1, inertia 191378.85149562338
# Iteration 2, inertia 190625.36054599597
# Iteration 3, inertia 190177.05924308882
# Iteration 4, inertia 190049.95884781584
# Iteration 5, inertia 189898.05472867604
# Iteration 6, inertia 189858.98359294687
# Iteration 7, inertia 189848.30585970002
# Iteration 8, inertia 189841.924169631
# Iteration 9, inertia 189839.1143544838
# Iteration 10, inertia 189838.07894680527
# Iteration 11, inertia 189837.92858628294
# Iteration 12, inertia 189837.8781246902
# Iteration 13, inertia 189837.87416127455
# Iteration 14, inertia 189837.8729168162
# Converged at iteration 14: center shift 9.325105925874401e-09 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 374834.9437514031
# Iteration 1, inertia 188899.46921115016
# Iteration 2, inertia 187930.85593649495
# Iteration 3, inertia 187680.85557469272
# Iteration 4, inertia 187552.90992602936
# Iteration 5, inertia 187517.82333440948
# Iteration 6, inertia 187514.2673172436
# Iteration 7, inertia 187511.96401156543
# Iteration 8, inertia 187505.39983332567
# Iteration 9, inertia 187479.03127107528
# Iteration 10, inertia 187414.74429133086
# Iteration 11, inertia 187403.4499587497
# Iteration 12, inertia 187403.27449280288
# Iteration 13, inertia 187403.26918640488
# Converged at iteration 13: center shift 0.0 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 376404.1943113155
# Iteration 1, inertia 189385.43515314115
# Iteration 2, inertia 189237.2618270272
# Iteration 3, inertia 189114.64914773678
# Iteration 4, inertia 188904.25485595985
# Iteration 5, inertia 188773.88255137776
# Iteration 6, inertia 188632.5033261033
# Iteration 7, inertia 188539.03489358662
# Iteration 8, inertia 188530.59828850426
# Iteration 9, inertia 188530.55965507322
# Converged at iteration 9: center shift 1.861210943984067e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 375775.58114937023
# Iteration 1, inertia 189748.4218111369
# Iteration 2, inertia 189177.7092429486
# Iteration 3, inertia 189108.40823982042
# Iteration 4, inertia 189023.3686812847
# Iteration 5, inertia 188984.61775536413
# Iteration 6, inertia 188933.03121655207
# Iteration 7, inertia 188832.85435413136
# Iteration 8, inertia 188749.11746992928
# Iteration 9, inertia 188717.9832291938
# Iteration 10, inertia 188717.9812540315
# Converged at iteration 10: center shift 1.2567445390052095e-32 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 376404.6863383807
# Iteration 1, inertia 189872.01396765988
# Iteration 2, inertia 189709.13096868643
# Iteration 3, inertia 189660.6912338809
# Iteration 4, inertia 189566.16611047403
# Iteration 5, inertia 189488.42954900034
# Iteration 6, inertia 189487.78049532988
# Iteration 7, inertia 189487.77964926464
# Converged at iteration 7: center shift 6.388470168673425e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 379563.5807181247
# Iteration 1, inertia 190336.23527748155
# Iteration 2, inertia 189798.8767209763
# Iteration 3, inertia 189676.5600338717
# Iteration 4, inertia 189590.90416587834
# Iteration 5, inertia 189535.3482159972
# Iteration 6, inertia 189464.44843610656
# Iteration 7, inertia 189400.52639925946
# Iteration 8, inertia 189344.07376435175
# Iteration 9, inertia 189302.29511952674
# Iteration 10, inertia 189271.7533003978
# Iteration 11, inertia 189233.08307558775
# Iteration 12, inertia 189192.04260543254
# Iteration 13, inertia 189176.88328970643
# Iteration 14, inertia 189175.81068552253
# Iteration 15, inertia 189175.58219081827
# Iteration 16, inertia 189175.3268801994
# Iteration 17, inertia 189174.97594889265
# Iteration 18, inertia 189173.98107140712
# Iteration 19, inertia 189170.8835836329
# Iteration 20, inertia 189165.13063595866
# Iteration 21, inertia 189162.82972502196
# Iteration 22, inertia 189162.46492107052
# Converged at iteration 22: center shift 3.195461894867759e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 379089.66024575324
# Iteration 1, inertia 190813.05845233245
# Iteration 2, inertia 190185.92650706746
# Iteration 3, inertia 190068.13141806345
# Iteration 4, inertia 189976.6666334278
# Iteration 5, inertia 189914.34587076918
# Iteration 6, inertia 189867.85457455073
# Iteration 7, inertia 189843.83258664285
# Iteration 8, inertia 189821.25620318076
# Iteration 9, inertia 189795.46057445052
# Iteration 10, inertia 189767.6429041908
# Iteration 11, inertia 189692.1656063148
# Iteration 12, inertia 189597.45189344656
# Iteration 13, inertia 189562.24711062235
# Iteration 14, inertia 189540.47247673638
# Iteration 15, inertia 189494.51842562034
# Iteration 16, inertia 189470.621872506
# Iteration 17, inertia 189465.60914968193
# Iteration 18, inertia 189463.84991777054
# Iteration 19, inertia 189463.03255794206
# Iteration 20, inertia 189462.67081898495
# Iteration 21, inertia 189462.53642395796
# Iteration 22, inertia 189462.427365844
# Iteration 23, inertia 189462.36478541352
# Iteration 24, inertia 189462.34002308897
# Iteration 25, inertia 189462.2735245719
# Iteration 26, inertia 189462.24238893818
# Iteration 27, inertia 189462.22962583372
# Iteration 28, inertia 189462.22442634925
# Converged at iteration 28: center shift 2.7129902801510687e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 379261.4020746655
# Iteration 1, inertia 189510.93548452013
# Iteration 2, inertia 188255.54006518863
# Iteration 3, inertia 188073.87456154157
# Iteration 4, inertia 188048.6626245922
# Iteration 5, inertia 188038.527528982
# Iteration 6, inertia 188032.43560298267
# Iteration 7, inertia 188021.70553225008
# Iteration 8, inertia 188007.1246512008
# Iteration 9, inertia 188002.5058032324
# Iteration 10, inertia 187993.765439165
# Iteration 11, inertia 187963.22054605235
# Iteration 12, inertia 187950.50714877632
# Iteration 13, inertia 187949.87979036852
# Iteration 14, inertia 187949.11091772068
# Iteration 15, inertia 187948.18658636845
# Iteration 16, inertia 187946.20586179828
# Iteration 17, inertia 187939.4389759852
# Iteration 18, inertia 187911.78324241444
# Iteration 19, inertia 187861.6413029301
# Iteration 20, inertia 187854.47123134386
# Iteration 21, inertia 187854.4674008728
# Converged at iteration 21: center shift 5.4294251761336785e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 379868.6552401396
# Iteration 1, inertia 190157.36932538854
# Iteration 2, inertia 189116.13490763906
# Iteration 3, inertia 188843.73666036414
# Iteration 4, inertia 188778.17462742375
# Iteration 5, inertia 188777.01286845258
# Iteration 6, inertia 188777.01221703496
# Converged at iteration 6: center shift 3.34444967071837e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 375133.25194625714
# Iteration 1, inertia 189770.04034003368
# Iteration 2, inertia 189228.27625696006
# Iteration 3, inertia 189101.1779661227
# Iteration 4, inertia 189034.85442019135
# Iteration 5, inertia 188974.3104588388
# Iteration 6, inertia 188894.60589535206
# Iteration 7, inertia 188797.97617966356
# Iteration 8, inertia 188766.8549229985
# Iteration 9, inertia 188756.08572902685
# Iteration 10, inertia 188755.38759271576
# Converged at iteration 10: center shift 6.487162824556041e-08 within tolerance 9.62771570643571e-08
# For n_clusters = 5 The average silhouette_score is : 0.021405447076565564
# Initialization complete
# Iteration 0, inertia 193406.767530285
# Iteration 1, inertia 190919.3173725886
# Iteration 2, inertia 189835.2225851755
# Iteration 3, inertia 189204.85153807068
# Iteration 4, inertia 189133.32748034535
# Iteration 5, inertia 189130.66798157376
# Iteration 6, inertia 189130.62436760272
# Iteration 7, inertia 189130.62301824696
# Converged at iteration 7: center shift 1.7479516097331024e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 371781.69716504886
# Iteration 1, inertia 188762.17946777592
# Iteration 2, inertia 187449.5218557886
# Iteration 3, inertia 186980.00877967887
# Iteration 4, inertia 186764.05694456698
# Iteration 5, inertia 186713.85718842037
# Iteration 6, inertia 186684.31286059605
# Iteration 7, inertia 186658.0105653055
# Iteration 8, inertia 186600.78214176744
# Iteration 9, inertia 186568.4380819137
# Iteration 10, inertia 186567.65068888833
# Iteration 11, inertia 186567.6351805462
# Converged at iteration 11: center shift 0.0 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 374864.4008039245
# Iteration 1, inertia 189015.01145002368
# Iteration 2, inertia 188841.89422961653
# Iteration 3, inertia 188695.2483771594
# Iteration 4, inertia 188452.50528968178
# Iteration 5, inertia 188281.263146824
# Iteration 6, inertia 188141.7064456242
# Iteration 7, inertia 188040.74493680062
# Iteration 8, inertia 188026.0990519938
# Iteration 9, inertia 188026.04870144808
# Iteration 10, inertia 188026.04751498057
# Iteration 11, inertia 188026.04719830447
# Converged at iteration 11: center shift 4.1907484931112425e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 372193.91430359107
# Iteration 1, inertia 189390.18319142846
# Iteration 2, inertia 187923.19848187754
# Iteration 3, inertia 187624.4876987378
# Iteration 4, inertia 187492.19150472764
# Iteration 5, inertia 187421.06774064674
# Iteration 6, inertia 187316.57970036782
# Iteration 7, inertia 187224.95605661278
# Iteration 8, inertia 187190.71268212897
# Iteration 9, inertia 187190.7083265208
# Converged at iteration 9: center shift 7.330884143575254e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 372391.6704294996
# Iteration 1, inertia 189190.73552153358
# Iteration 2, inertia 188457.32705154334
# Iteration 3, inertia 188392.19736841667
# Iteration 4, inertia 188272.88406132063
# Iteration 5, inertia 188234.82960452265
# Iteration 6, inertia 188234.81321312094
# Iteration 7, inertia 188234.81174056217
# Converged at iteration 7: center shift 3.17061518554831e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 376026.28924355644
# Iteration 1, inertia 189569.20846231427
# Iteration 2, inertia 188992.19121994317
# Iteration 3, inertia 188853.07608570548
# Iteration 4, inertia 188795.8820919136
# Iteration 5, inertia 188771.79495722652
# Iteration 6, inertia 188742.41220555094
# Iteration 7, inertia 188709.9978257093
# Iteration 8, inertia 188653.77315431
# Iteration 9, inertia 188585.07550091285
# Iteration 10, inertia 188519.161681134
# Iteration 11, inertia 188461.72049615608
# Iteration 12, inertia 188405.14079035202
# Iteration 13, inertia 188352.48557031606
# Iteration 14, inertia 188318.52017621387
# Iteration 15, inertia 188300.40154917692
# Iteration 16, inertia 188257.8755170415
# Iteration 17, inertia 188227.27605293586
# Iteration 18, inertia 188225.40309332425
# Iteration 19, inertia 188225.19719991897
# Iteration 20, inertia 188224.92848419
# Iteration 21, inertia 188224.4968812969
# Iteration 22, inertia 188223.10705723666
# Iteration 23, inertia 188218.978419932
# Iteration 24, inertia 188213.21375544707
# Iteration 25, inertia 188211.02790753279
# Converged at iteration 25: center shift 6.400457960053369e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 376598.09089335706
# Iteration 1, inertia 190390.42691070138
# Iteration 2, inertia 189709.22659749727
# Iteration 3, inertia 189538.3205621876
# Iteration 4, inertia 189388.28221482987
# Iteration 5, inertia 189304.1502114467
# Iteration 6, inertia 189245.44800905682
# Iteration 7, inertia 189204.7054441217
# Iteration 8, inertia 189157.4976942375
# Iteration 9, inertia 189095.04399538736
# Iteration 10, inertia 189037.3650498155
# Iteration 11, inertia 188990.78826917583
# Iteration 12, inertia 188956.02852676428
# Iteration 13, inertia 188905.08247071897
# Iteration 14, inertia 188892.28028192886
# Iteration 15, inertia 188890.06150199723
# Iteration 16, inertia 188888.63462989937
# Iteration 17, inertia 188887.9708236618
# Iteration 18, inertia 188887.75065682761
# Iteration 19, inertia 188887.59750483642
# Iteration 20, inertia 188887.50842117256
# Iteration 21, inertia 188887.4761214133
# Iteration 22, inertia 188887.44443378766
# Iteration 23, inertia 188887.39457040318
# Iteration 24, inertia 188887.37309111396
# Iteration 25, inertia 188887.36112244346
# Iteration 26, inertia 188887.35630969884
# Converged at iteration 26: center shift 2.761746629477656e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 376175.93000335945
# Iteration 1, inertia 188930.19407565374
# Iteration 2, inertia 187583.61355277212
# Iteration 3, inertia 187366.4875990561
# Iteration 4, inertia 187345.0634058114
# Iteration 5, inertia 187340.60759330873
# Iteration 6, inertia 187333.607153625
# Iteration 7, inertia 187319.89759659732
# Iteration 8, inertia 187314.99897551996
# Iteration 9, inertia 187314.5860183744
# Iteration 10, inertia 187313.6718086108
# Iteration 11, inertia 187310.93086019
# Iteration 12, inertia 187295.78719890834
# Iteration 13, inertia 187266.22551024868
# Iteration 14, inertia 187262.5746923211
# Iteration 15, inertia 187261.84156417495
# Iteration 16, inertia 187261.12576437785
# Iteration 17, inertia 187260.28054805705
# Iteration 18, inertia 187258.84694303072
# Iteration 19, inertia 187254.43734335754
# Iteration 20, inertia 187237.84872561923
# Iteration 21, inertia 187190.02496144702
# Iteration 22, inertia 187166.90691065302
# Iteration 23, inertia 187166.90092783116
# Converged at iteration 23: center shift 9.248892219814473e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 377653.4653972122
# Iteration 1, inertia 189629.57168225123
# Iteration 2, inertia 188561.09022251004
# Iteration 3, inertia 188298.05854674266
# Iteration 4, inertia 188232.75671577107
# Iteration 5, inertia 188231.24705439416
# Iteration 6, inertia 188231.24625297013
# Converged at iteration 6: center shift 6.615411291714168e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 371977.37634388194
# Iteration 1, inertia 189155.28104554984
# Iteration 2, inertia 188525.31030191854
# Iteration 3, inertia 188323.9548006987
# Iteration 4, inertia 188173.62232445565
# Iteration 5, inertia 188093.31724264316
# Iteration 6, inertia 188038.05596095746
# Iteration 7, inertia 187941.93619690585
# Iteration 8, inertia 187889.7433526171
# Iteration 9, inertia 187860.98915647354
# Iteration 10, inertia 187858.16357934286
# Iteration 11, inertia 187858.14245585413
# Iteration 12, inertia 187858.13798988995
# Converged at iteration 12: center shift 3.4854758437918885e-08 within tolerance 9.62771570643571e-08
# For n_clusters = 6 The average silhouette_score is : 0.022765405435408066
# Initialization complete
# Iteration 0, inertia 193284.2519940211
# Iteration 1, inertia 190667.866511326
# Iteration 2, inertia 189575.44878462155
# Iteration 3, inertia 188945.69174736936
# Iteration 4, inertia 188875.49883164823
# Iteration 5, inertia 188872.933263903
# Iteration 6, inertia 188872.88839752148
# Iteration 7, inertia 188872.88695645705
# Converged at iteration 7: center shift 5.4124623278938695e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 369631.1811667422
# Iteration 1, inertia 188301.51617705522
# Iteration 2, inertia 186964.70897560703
# Iteration 3, inertia 186437.3920413294
# Iteration 4, inertia 186161.28055971218
# Iteration 5, inertia 186101.0880895286
# Iteration 6, inertia 186071.52260988107
# Iteration 7, inertia 186046.03046543917
# Iteration 8, inertia 185990.06647228333
# Iteration 9, inertia 185956.17334862356
# Iteration 10, inertia 185955.37008432669
# Iteration 11, inertia 185955.35918476572
# Converged at iteration 11: center shift 9.785441477999511e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 370865.49974808004
# Iteration 1, inertia 188179.6889426675
# Iteration 2, inertia 187962.498009736
# Iteration 3, inertia 187815.06393918832
# Iteration 4, inertia 187601.50669572374
# Iteration 5, inertia 187447.1172618415
# Iteration 6, inertia 187312.00350731376
# Iteration 7, inertia 187214.99897282745
# Iteration 8, inertia 187189.14476694216
# Iteration 9, inertia 187189.08275395838
# Iteration 10, inertia 187189.08126095732
# Iteration 11, inertia 187189.0803240731
# Iteration 12, inertia 187189.07999174434
# Iteration 13, inertia 187189.07953949744
# Iteration 14, inertia 187189.07921134259
# Converged at iteration 14: center shift 3.5252181246920786e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 370930.8225216543
# Iteration 1, inertia 189175.3017019134
# Iteration 2, inertia 187711.3512851453
# Iteration 3, inertia 187409.5227545913
# Iteration 4, inertia 187269.00838943955
# Iteration 5, inertia 187169.16463667311
# Iteration 6, inertia 187052.2648240791
# Iteration 7, inertia 186945.36552937436
# Iteration 8, inertia 186897.87044314118
# Iteration 9, inertia 186892.39948163484
# Iteration 10, inertia 186892.39833272476
# Converged at iteration 10: center shift 5.39835362167773e-09 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 370566.41821885516
# Iteration 1, inertia 188826.75805112536
# Iteration 2, inertia 188062.77470214426
# Iteration 3, inertia 187969.31991726457
# Iteration 4, inertia 187849.93446731716
# Iteration 5, inertia 187818.13064951875
# Iteration 6, inertia 187818.10768963955
# Iteration 7, inertia 187818.09614831672
# Iteration 8, inertia 187818.06441888754
# Iteration 9, inertia 187818.00594183386
# Iteration 10, inertia 187817.9087823322
# Iteration 11, inertia 187817.5090588808
# Iteration 12, inertia 187816.60459853514
# Iteration 13, inertia 187815.47693202624
# Iteration 14, inertia 187812.624165903
# Iteration 15, inertia 187806.73636553204
# Iteration 16, inertia 187800.8845965048
# Iteration 17, inertia 187799.32170740672
# Iteration 18, inertia 187799.21063743712
# Iteration 19, inertia 187799.20424610915
# Converged at iteration 19: center shift 1.6676067003200567e-32 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 373442.94315527467
# Iteration 1, inertia 188663.40823014075
# Iteration 2, inertia 188077.46556161382
# Iteration 3, inertia 187931.82912276124
# Iteration 4, inertia 187703.7735994438
# Iteration 5, inertia 187133.8917444507
# Iteration 6, inertia 186863.76356572012
# Iteration 7, inertia 186811.00120001566
# Iteration 8, inertia 186798.89306444867
# Iteration 9, inertia 186792.4584649825
# Iteration 10, inertia 186790.093837563
# Iteration 11, inertia 186789.215308517
# Iteration 12, inertia 186788.41913856933
# Iteration 13, inertia 186786.5720342391
# Iteration 14, inertia 186780.29904089574
# Iteration 15, inertia 186751.9012740479
# Iteration 16, inertia 186706.3982951799
# Iteration 17, inertia 186700.75131705301
# Iteration 18, inertia 186700.7433003841
# Converged at iteration 18: center shift 6.783297582076825e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 370753.65316526487
# Iteration 1, inertia 189158.99106106567
# Iteration 2, inertia 188515.8425636713
# Iteration 3, inertia 188337.8564604014
# Iteration 4, inertia 188207.64933919016
# Iteration 5, inertia 188147.98463032668
# Iteration 6, inertia 188093.9117820282
# Iteration 7, inertia 188036.4904105759
# Iteration 8, inertia 187977.52444784078
# Iteration 9, inertia 187931.399328066
# Iteration 10, inertia 187904.69269791376
# Iteration 11, inertia 187846.3792083823
# Iteration 12, inertia 187767.52459966994
# Iteration 13, inertia 187633.0606475572
# Iteration 14, inertia 187520.12464714254
# Iteration 15, inertia 187487.9900797737
# Iteration 16, inertia 187479.7870967261
# Iteration 17, inertia 187476.4198288291
# Iteration 18, inertia 187475.1751804514
# Iteration 19, inertia 187475.0395483086
# Iteration 20, inertia 187475.01623587075
# Converged at iteration 20: center shift 2.6948473064854784e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 374260.19894422597
# Iteration 1, inertia 188500.1668670878
# Iteration 2, inertia 187119.36868043992
# Iteration 3, inertia 186875.453924239
# Iteration 4, inertia 186840.84744310938
# Iteration 5, inertia 186787.11613645643
# Iteration 6, inertia 186763.9254872723
# Iteration 7, inertia 186751.99504680937
# Iteration 8, inertia 186750.00095326675
# Iteration 9, inertia 186748.83833744447
# Iteration 10, inertia 186746.75250085793
# Iteration 11, inertia 186741.49409900306
# Iteration 12, inertia 186721.48055926486
# Iteration 13, inertia 186698.1267209598
# Iteration 14, inertia 186694.8197514129
# Iteration 15, inertia 186694.21041413562
# Iteration 16, inertia 186693.49800834755
# Iteration 17, inertia 186692.61687093787
# Iteration 18, inertia 186690.838777448
# Iteration 19, inertia 186684.83107419725
# Iteration 20, inertia 186660.095983313
# Iteration 21, inertia 186608.36381423663
# Iteration 22, inertia 186600.27362403498
# Iteration 23, inertia 186600.2688324853
# Iteration 24, inertia 186600.26817650843
# Converged at iteration 24: center shift 3.723021483491526e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 372945.6433193253
# Iteration 1, inertia 188250.7681155415
# Iteration 2, inertia 187073.04749670188
# Iteration 3, inertia 186741.6242384853
# Iteration 4, inertia 186691.5447396913
# Iteration 5, inertia 186690.97578014748
# Iteration 6, inertia 186690.96659276044
# Iteration 7, inertia 186690.96554798252
# Converged at iteration 7: center shift 1.5908167087769562e-32 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 369456.2095064435
# Iteration 1, inertia 188742.72054976207
# Iteration 2, inertia 188075.38882449668
# Iteration 3, inertia 187843.7431165661
# Iteration 4, inertia 187720.89824710574
# Iteration 5, inertia 187666.27274899525
# Iteration 6, inertia 187613.88611341378
# Iteration 7, inertia 187523.4509727292
# Iteration 8, inertia 187450.22520055113
# Iteration 9, inertia 187425.07645222938
# Iteration 10, inertia 187422.40325487102
# Iteration 11, inertia 187422.3737620099
# Iteration 12, inertia 187422.368984497
# Converged at iteration 12: center shift 3.222193939869098e-08 within tolerance 9.62771570643571e-08
# For n_clusters = 7 The average silhouette_score is : 0.023800661724853654
# Initialization complete
# Iteration 0, inertia 193314.7050412656
# Iteration 1, inertia 191558.0578312755
# Iteration 2, inertia 190986.09718505392
# Iteration 3, inertia 190474.20558213734
# Iteration 4, inertia 190389.9746832255
# Iteration 5, inertia 190093.25243081446
# Iteration 6, inertia 189651.2447422802
# Iteration 7, inertia 189594.55220422504
# Iteration 8, inertia 189594.04538172873
# Iteration 9, inertia 189594.04039901975
# Iteration 10, inertia 189594.03956202173
# Converged at iteration 10: center shift 0.0 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 193078.0462100537
# Iteration 1, inertia 191027.92580822733
# Iteration 2, inertia 190350.18806954147
# Iteration 3, inertia 189511.9424332619
# Iteration 4, inertia 188687.90985024694
# Iteration 5, inertia 188587.67459919563
# Iteration 6, inertia 188585.67003968157
# Iteration 7, inertia 188585.64821935116
# Converged at iteration 7: center shift 4.5352849405731644e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 365778.4251689914
# Iteration 1, inertia 187621.29675228283
# Iteration 2, inertia 187032.85124809752
# Iteration 3, inertia 186807.97666473803
# Iteration 4, inertia 186538.45119002654
# Iteration 5, inertia 186310.88853880792
# Iteration 6, inertia 186112.68276322648
# Iteration 7, inertia 186002.94646742273
# Iteration 8, inertia 185979.73479416297
# Iteration 9, inertia 185979.67575553997
# Iteration 10, inertia 185979.6698742387
# Iteration 11, inertia 185979.66685933218
# Iteration 12, inertia 185979.66498475955
# Iteration 13, inertia 185979.6636732377
# Iteration 14, inertia 185979.66170987947
# Iteration 15, inertia 185979.65778946152
# Iteration 16, inertia 185979.65595801466
# Iteration 17, inertia 185979.65319171295
# Iteration 18, inertia 185979.64992522512
# Iteration 19, inertia 185979.64621297008
# Iteration 20, inertia 185979.64153010066
# Iteration 21, inertia 185979.63703991365
# Iteration 22, inertia 185979.63453436655
# Iteration 23, inertia 185979.6329021702
# Iteration 24, inertia 185979.6321475909
# Iteration 25, inertia 185979.63147584436
# Converged at iteration 25: center shift 7.287367048664895e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 364363.44476296083
# Iteration 1, inertia 188515.16812001143
# Iteration 2, inertia 187412.5888015344
# Iteration 3, inertia 187154.17647322977
# Iteration 4, inertia 187017.61882919652
# Iteration 5, inertia 186812.25775315432
# Iteration 6, inertia 186638.5463192541
# Iteration 7, inertia 186603.5011056007
# Iteration 8, inertia 186588.5738427112
# Iteration 9, inertia 186562.61303078342
# Iteration 10, inertia 186543.40144090433
# Iteration 11, inertia 186468.2698092724
# Iteration 12, inertia 186375.9171879702
# Iteration 13, inertia 186369.1479093611
# Iteration 14, inertia 186366.33514995954
# Iteration 15, inertia 186354.0910311109
# Iteration 16, inertia 186322.80373810595
# Iteration 17, inertia 186311.71341910458
# Iteration 18, inertia 186311.5875906552
# Iteration 19, inertia 186311.54206489807
# Iteration 20, inertia 186311.52916447137
# Iteration 21, inertia 186311.52450797491
# Iteration 22, inertia 186311.52161056263
# Iteration 23, inertia 186311.5192665304
# Iteration 24, inertia 186311.51834853037
# Iteration 25, inertia 186311.51669186947
# Converged at iteration 25: center shift 4.763080701321841e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 360539.6794812187
# Iteration 1, inertia 186772.8725053983
# Iteration 2, inertia 186279.6377508536
# Iteration 3, inertia 186175.3521512716
# Iteration 4, inertia 186110.68702420368
# Iteration 5, inertia 186039.89817205857
# Iteration 6, inertia 185946.88852877746
# Iteration 7, inertia 185911.99093444968
# Iteration 8, inertia 185899.24311114554
# Iteration 9, inertia 185899.18331770977
# Iteration 10, inertia 185899.1202102916
# Iteration 11, inertia 185899.06864525322
# Iteration 12, inertia 185899.02721108493
# Iteration 13, inertia 185898.96527576353
# Iteration 14, inertia 185898.9339371301
# Iteration 15, inertia 185898.9281043661
# Iteration 16, inertia 185898.92450632204
# Converged at iteration 16: center shift 3.889126021390289e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 193171.82341198777
# Iteration 1, inertia 190982.06688495242
# Iteration 2, inertia 190314.3880875771
# Iteration 3, inertia 190160.4080168736
# Iteration 4, inertia 190157.45696979383
# Iteration 5, inertia 190157.45584230064
# Converged at iteration 5: center shift 4.80324624161249e-34 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 192911.3953281681
# Iteration 1, inertia 190546.16459592266
# Iteration 2, inertia 189483.15488920678
# Iteration 3, inertia 189261.7161991544
# Iteration 4, inertia 189232.54158695394
# Iteration 5, inertia 189232.06327453168
# Iteration 6, inertia 189232.0258697689
# Iteration 7, inertia 189232.02079036276
# Iteration 8, inertia 189232.0184511594
# Iteration 9, inertia 189232.01653613572
# Converged at iteration 9: center shift 0.0 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 193028.9388025737
# Iteration 1, inertia 190783.66953603338
# Iteration 2, inertia 190216.36679827436
# Iteration 3, inertia 190073.5565607796
# Iteration 4, inertia 190069.5934983389
# Iteration 5, inertia 190069.5890606233
# Converged at iteration 5: center shift 2.457928065987623e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 370247.3741806028
# Iteration 1, inertia 188414.87862341807
# Iteration 2, inertia 187025.57965318064
# Iteration 3, inertia 186636.4977141716
# Iteration 4, inertia 186419.19646554196
# Iteration 5, inertia 186247.14456684986
# Iteration 6, inertia 186183.21928967084
# Iteration 7, inertia 186103.80001804663
# Iteration 8, inertia 186094.06680263736
# Iteration 9, inertia 186094.0608110644
# Converged at iteration 9: center shift 6.73031010489092e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 368750.4283389062
# Iteration 1, inertia 187731.73236744117
# Iteration 2, inertia 186709.77930875123
# Iteration 3, inertia 186376.65241203993
# Iteration 4, inertia 186150.07563288644
# Iteration 5, inertia 186009.45789638918
# Iteration 6, inertia 185965.4799962598
# Iteration 7, inertia 185926.14921615264
# Iteration 8, inertia 185866.28949446694
# Iteration 9, inertia 185800.21753922768
# Iteration 10, inertia 185742.63125712157
# Iteration 11, inertia 185703.12007171355
# Iteration 12, inertia 185601.2035286009
# Iteration 13, inertia 185535.09413915346
# Iteration 14, inertia 185524.337869871
# Iteration 15, inertia 185519.65165777024
# Iteration 16, inertia 185517.61524213298
# Iteration 17, inertia 185516.82161452578
# Iteration 18, inertia 185516.39050095237
# Iteration 19, inertia 185516.2494603724
# Iteration 20, inertia 185516.23233260756
# Iteration 21, inertia 185516.2298566492
# Iteration 22, inertia 185516.22769813702
# Converged at iteration 22: center shift 4.715686702236322e-08 within tolerance 9.62771570643571e-08
# For n_clusters = 8 The average silhouette_score is : 0.024684008250386025
# Initialization complete
# Iteration 0, inertia 193252.74660629296
# Iteration 1, inertia 191170.29398008905
# Iteration 2, inertia 189865.33303192796
# Iteration 3, inertia 189127.39521378477
# Iteration 4, inertia 189015.16972085965
# Iteration 5, inertia 188721.43440763638
# Iteration 6, inertia 188288.24857224672
# Iteration 7, inertia 188232.50006439682
# Iteration 8, inertia 188231.97236507022
# Iteration 9, inertia 188231.9670999174
# Converged at iteration 9: center shift 4.294416980252559e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 192991.82418621008
# Iteration 1, inertia 190725.55068686913
# Iteration 2, inertia 189599.30414074758
# Iteration 3, inertia 188607.09471680893
# Iteration 4, inertia 187786.83947279584
# Iteration 5, inertia 187686.5994408504
# Iteration 6, inertia 187684.61085964972
# Iteration 7, inertia 187684.58823947396
# Converged at iteration 7: center shift 4.646013251834501e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 364878.53950381716
# Iteration 1, inertia 187360.87928648744
# Iteration 2, inertia 186772.15520196932
# Iteration 3, inertia 186546.72675582848
# Iteration 4, inertia 186282.8076608142
# Iteration 5, inertia 186058.22367538075
# Iteration 6, inertia 185856.22200002364
# Iteration 7, inertia 185746.51023428564
# Iteration 8, inertia 185723.28699632114
# Iteration 9, inertia 185723.22080475622
# Iteration 10, inertia 185723.2003651403
# Iteration 11, inertia 185723.1820838216
# Iteration 12, inertia 185723.16762253045
# Iteration 13, inertia 185723.16090026664
# Iteration 14, inertia 185723.1558669915
# Iteration 15, inertia 185723.15439218868
# Iteration 16, inertia 185723.1529815652
# Converged at iteration 16: center shift 8.005935681293136e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 362809.87686140684
# Iteration 1, inertia 188255.98824970823
# Iteration 2, inertia 187133.82981231555
# Iteration 3, inertia 186843.17788279545
# Iteration 4, inertia 186667.9712662644
# Iteration 5, inertia 186437.94608824493
# Iteration 6, inertia 186322.6155879679
# Iteration 7, inertia 186304.5292176261
# Iteration 8, inertia 186282.59526667584
# Iteration 9, inertia 186258.4845272261
# Iteration 10, inertia 186211.82174030782
# Iteration 11, inertia 186100.9671382585
# Iteration 12, inertia 186076.6016748697
# Iteration 13, inertia 186074.4551198232
# Iteration 14, inertia 186065.88037932108
# Iteration 15, inertia 186038.70105031843
# Iteration 16, inertia 186020.04646237526
# Iteration 17, inertia 186018.68052082555
# Iteration 18, inertia 186018.60134096447
# Iteration 19, inertia 186018.56247530764
# Iteration 20, inertia 186018.53846634994
# Iteration 21, inertia 186018.52510055402
# Iteration 22, inertia 186018.51281423672
# Iteration 23, inertia 186018.49454691212
# Iteration 24, inertia 186018.4733928789
# Iteration 25, inertia 186018.4495745645
# Iteration 26, inertia 186018.43423350388
# Iteration 27, inertia 186018.41680298644
# Iteration 28, inertia 186018.38750782647
# Iteration 29, inertia 186018.31006190795
# Iteration 30, inertia 186018.16089856025
# Iteration 31, inertia 186017.85059269253
# Iteration 32, inertia 186017.21918170038
# Iteration 33, inertia 186015.62374910532
# Iteration 34, inertia 186009.6672441793
# Iteration 35, inertia 185984.92296289242
# Iteration 36, inertia 185922.85570451585
# Iteration 37, inertia 185902.6672419925
# Iteration 38, inertia 185902.63811673038
# Iteration 39, inertia 185902.63709731007
# Converged at iteration 39: center shift 1.754705112660465e-32 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 356650.80108521855
# Iteration 1, inertia 186005.63648164982
# Iteration 2, inertia 185492.27524901158
# Iteration 3, inertia 185356.62964348428
# Iteration 4, inertia 185233.73350832704
# Iteration 5, inertia 185138.5504984876
# Iteration 6, inertia 185045.13846675522
# Iteration 7, inertia 185018.3704023618
# Iteration 8, inertia 185006.872630296
# Iteration 9, inertia 185006.8124482181
# Iteration 10, inertia 185006.7550202632
# Iteration 11, inertia 185006.7082991546
# Iteration 12, inertia 185006.66284111753
# Iteration 13, inertia 185006.6013724502
# Iteration 14, inertia 185006.5673687568
# Iteration 15, inertia 185006.55946021513
# Iteration 16, inertia 185006.5570678873
# Converged at iteration 16: center shift 8.518763600876643e-08 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 192991.72447489956
# Iteration 1, inertia 190534.36086335545
# Iteration 2, inertia 189820.05823646055
# Iteration 3, inertia 189670.93092004763
# Iteration 4, inertia 189668.22162887262
# Iteration 5, inertia 189668.21873058073
# Iteration 6, inertia 189668.21779817867
# Converged at iteration 6: center shift 1.606369748144576e-32 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 192779.8496441786
# Iteration 1, inertia 190230.20215849238
# Iteration 2, inertia 189146.4132294801
# Iteration 3, inertia 188926.5644865412
# Iteration 4, inertia 188897.44714946274
# Iteration 5, inertia 188896.8338934824
# Iteration 6, inertia 188896.80687795283
# Iteration 7, inertia 188896.79943375743
# Iteration 8, inertia 188896.79786451533
# Converged at iteration 8: center shift 0.0 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 192988.01204137603
# Iteration 1, inertia 190499.64696936304
# Iteration 2, inertia 189748.42218391737
# Iteration 3, inertia 189595.12493924098
# Iteration 4, inertia 189588.25515628955
# Iteration 5, inertia 189577.82181888318
# Iteration 6, inertia 189524.67415776526
# Iteration 7, inertia 189476.69476819667
# Iteration 8, inertia 189474.97301370616
# Iteration 9, inertia 189474.96113357804
# Iteration 10, inertia 189474.96027531626
# Converged at iteration 10: center shift 1.3385019202841152e-32 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 367624.9655900728
# Iteration 1, inertia 187902.64854420937
# Iteration 2, inertia 186408.05441603492
# Iteration 3, inertia 186014.33809589746
# Iteration 4, inertia 185819.00030921248
# Iteration 5, inertia 185649.29162004957
# Iteration 6, inertia 185585.1306555092
# Iteration 7, inertia 185505.6502658122
# Iteration 8, inertia 185495.82026494964
# Iteration 9, inertia 185495.79245165642
# Iteration 10, inertia 185495.78892868094
# Iteration 11, inertia 185495.7884983941
# Converged at iteration 11: center shift 6.615836492931239e-33 within tolerance 9.62771570643571e-08
# Initialization complete
# Iteration 0, inertia 364787.54025123164
# Iteration 1, inertia 187089.43836170388
# Iteration 2, inertia 186064.0856344581
# Iteration 3, inertia 185724.5270767183
# Iteration 4, inertia 185493.71612911075
# Iteration 5, inertia 185373.1703129232
# Iteration 6, inertia 185329.64345870697
# Iteration 7, inertia 185276.8443769019
# Iteration 8, inertia 185205.51484628784
# Iteration 9, inertia 185143.965193851
# Iteration 10, inertia 185087.89306947615
# Iteration 11, inertia 184987.1247537852
# Iteration 12, inertia 184906.89298193905
# Iteration 13, inertia 184895.66624363128
# Iteration 14, inertia 184890.7018472838
# Iteration 15, inertia 184888.4178099336
# Iteration 16, inertia 184887.60693649136
# Iteration 17, inertia 184887.24485896455
# Iteration 18, inertia 184887.00868141992
# Iteration 19, inertia 184886.9349916453
# Iteration 20, inertia 184886.9293312984
# Converged at iteration 20: center shift 8.066566865649184e-08 within tolerance 9.62771570643571e-08
# For n_clusters = 9 The average silhouette_score is : 0.02587817624273277
